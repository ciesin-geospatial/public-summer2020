# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fiona
import geopandas as gpd
import folium
import os
from folium.plugins import MarkerCluster
from math import radians, sin, cos, acos

# %%
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', None)

# %%
cols = ['id', 'admin1', 'admin2', 'name_full', 'name_short', 'type_original', 'type_cleaned', 
        'latitude', 'longitude', 'source']

# %%
saveDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Cleaned data\MOZ"

# %% [markdown]
# # Examine the new unique points
#
# New unique points are data points that are more than 100 meters away from PLM data points.

# %% [markdown]
# ## Adding new ISS points

# %%
dataDir = r'C:\\Users\\DUANYUEYUN\\Documents\\ArcGIS\\Projects\\MOZ-cleaning_0729\\MOZ-cleaning_0729.gdb'

# %%
iss_new = gpd.read_file(dataDir, driver='FileGDB', 
                   layer= 'ISS_new')
plm = pd.read_csv(saveDir + '\PLM_cleaned_0729.csv')
# Uppercase first letter in admin1
plm['admin1'] = plm['admin1'].str.title()
# Remove whitespace in admin2
plm['admin2'] = plm['admin2'].str.strip()

# %%
print("Number of PLM points:", plm.shape[0])
print("Number of new ISS points:", iss_new.shape[0])
# Out:
# Number of PLM points: 1712
# Number of new ISS points: 34

# %%
# combine PLM and ISS
df = pd.concat([iss_new[cols], plm[cols]], axis=0)

# %% [markdown]
# Consider rows with identical values in `admin1`, `admin2`, `name_short` and `type_cleaned` as duplicates.

# %%
duplicates = df[df.duplicated(subset=['admin1', 'admin2', 'name_short', 'type_cleaned'],
                keep=False)] \
.sort_values(['admin1', 'admin2', 'name_short', 'type_cleaned', 'source'])

# %%
print("Number of duplicates identified for now:",
     duplicates[duplicates.duplicated(subset=['admin1', 'admin2', 'name_short', 'type_cleaned'])] \
.sort_values(['admin1', 'admin2', 'name_short', 'type_cleaned']).shape[0])
# Out:
# Number of duplicates identified for now: 29

# %% [markdown]
# If the pair of duplicate points are within 1km from each other, consider them as duplicates. Otherwise they are considered distinct health facilities.

# %%
def distance(origin, destination):
    lat1, lon1 = origin
    lat2, lon2 = destination
    lat1 = radians(lat1)
    lat2 = radians(lat2)
    lon1 = radians(lon1)
    lon2 = radians(lon2)
    dist = 6371.01 * acos(sin(lat1)*sin(lat2) + cos(lat1)*cos(lat2)*cos(lon1 - lon2))
    return dist

# %%
distances = []
same_sources = []
dups = []
for i in range(0, 58, 2):
    row1 = duplicates.iloc[i,:]
    row2 = duplicates.iloc[i+1,:]
    if row1['source'] == row2['source']:
        same_sources.append(True)
        same_sources.append(True)
    else:
        same_sources.append(False)
        same_sources.append(False)
    
    p1 = (row1['longitude'], row1['latitude'])
    p2 = (row2['longitude'], row2['latitude'])
    dist = distance(p1,p2)
    distances.append(dist)
    distances.append(dist)
    
    if dist < 1:
        dups.append(True)
        dups.append(False)
    else:
        dups.append(False)
        dups.append(False)

# %%
duplicates['distance'] = distances
duplicates['same_source'] = same_sources
duplicates['duplicate'] = dups

# %%
duplicates
# Out:
#           id            admin1             admin2             name_full  \
# 34      HF35      Cabo Delgado    Cidade De Pemba             CS Mahate
# 35      HF36      Cabo Delgado    Cidade De Pemba             CS Mahate
# 0      64044      Cabo Delgado             Metuge              CS MIEZE
# 62      HF63      Cabo Delgado             Metuge              CS Mieze
# 1      62742      Cabo Delgado  Mocimboa Da Praia          CS NANDUADUA
# 70      HF71      Cabo Delgado  Mocimboa Da Praia          CS Nanduadua
# 257    HF258              Gaza   Xai-Xai Distrito            CS Banhine
# 258    HF259              Gaza   Xai-Xai Distrito            CS Banhine
# 304    HF305         Inhambane            Homoine           CS Mafuiane
# 305    HF306         Inhambane            Homoine           CS Mafuiane
# 2      63655         Inhambane          Inhassoro          CS INHASSORO
# 325    HF326         Inhambane          Inhassoro          CS Inhassoro
# 3      63652         Inhambane             Mabote             CS MABOTE
# 338    HF339         Inhambane             Mabote             CS Mabote
# 4      63163         Inhambane           Massinga         CS NHACHENGUE
# 354    HF355         Inhambane           Massinga         CS Nhachengue
# 5      63654         Inhambane         Vilanculos            CS MACUNHE
# 389    HF390         Inhambane         Vilanculos            CS Macunhe
# 6      63653         Inhambane         Vilanculos        CS VIALANCULOS
# 394    HF395         Inhambane         Vilanculos        CS Vialanculos
# 506    HF507            Manica        Sussundenga              CS Darue
# 507    HF508            Manica        Sussundenga              CS Darue
# 517    HF518            Manica        Sussundenga           CS Sembezea
# 518    HF519            Manica        Sussundenga           CS Sembezea
# 529    HF530            Manica            Vanduzi          CS Chigodole
# 530    HF531            Manica            Vanduzi          CS Chigodole
# 7      63371  Maputo Provincia         Marracuene         CS ABEL JAFAR
# 663    HF664  Maputo Provincia         Marracuene         CS Abel Jafar
# 8      63563  Maputo Provincia           Namaacha           CS NAMAACHA
# 709    HF710  Maputo Provincia           Namaacha           CS Namaacha
# 10     63971           Nampula             Malema             CS NAKATA
# 762    HF763           Nampula             Malema             CS Nakata
# 13     63648            Sofala          Chibabava             CS NHANGO
# 1188  HF1190            Sofala          Chibabava             CS Nhango
# 1357  HF1359              Tete     Cidade De Tete            CS Militar
# 1370  HF1372              Tete     Cidade De Tete  Posto Medico Militar
# 16     63111              Tete              Zumbo           CS CHISSAVO
# 1438  HF1440              Tete              Zumbo           CS Chissavo
# 18     62679          Zambezia                Ile            CS UALASSE
# 1535  HF1537          Zambezia                Ile            CS Ualasse
# 19     64039          Zambezia         Inhassunge      CS PALANE-MUCULA
# 1543  HF1545          Zambezia         Inhassunge      CS Palane-Mucula
# 22     63161          Zambezia            Milange            CS MILANGE
# 1582  HF1584          Zambezia            Milange            CS Milange
# 25     63125          Zambezia             Mocuba             HD MOCUBA
# 1614  HF1616          Zambezia             Mocuba             HD Mocuba
# 23     62686          Zambezia             Mocuba            CS MUANACO
# 1602  HF1604          Zambezia             Mocuba            CS Muanaco
# 27     63110          Zambezia         Morrumbala         CS MORRUMBALA
# 1653  HF1655          Zambezia         Morrumbala         CS Morrumbala
# 28     63250          Zambezia          Namacurra              CS MBAWA
# 1671  HF1673          Zambezia          Namacurra              CS Mbawa
# 29     64018          Zambezia             Pebane       CS ALTO MAGANHA
# 1699  HF1701          Zambezia             Pebane       CS Alto Maganha
# 30     63053          Zambezia             Pebane            CS MIHECUE
# 1703  HF1705          Zambezia             Pebane            CS Mihecue
# 31     63054          Zambezia             Pebane          CS TXALALANE
# 1710  HF1712          Zambezia             Pebane          CS Txalalane
#
#          name_short    type_original            type_cleaned   latitude  \
# 34           Mahate               CS         Centro de Saúde -13.019118
# 35           Mahate               CS         Centro de Saúde -13.019118
# 0             Mieze  HEALTH_FACILITY         Centro de Saúde -13.107240
# 62            Mieze               CS         Centro de Saúde -13.059200
# 1         Nanduadua  HEALTH_FACILITY         Centro de Saúde -11.349539
# 70        Nanduadua               CS         Centro de Saúde -11.350993
# 257         Banhine               CS         Centro de Saúde -24.809640
# 258         Banhine               CS         Centro de Saúde -25.152500
# 304        Mafuiane               CS         Centro de Saúde -24.012520
# 305        Mafuiane               CS         Centro de Saúde -24.012460
# 2         Inhassoro  HEALTH_FACILITY         Centro de Saúde -21.710036
# 325       Inhassoro               CS         Centro de Saúde -21.539157
# 3            Mabote  HEALTH_FACILITY         Centro de Saúde -22.039657
# 338          Mabote               CS         Centro de Saúde -22.040595
# 4        Nhachengue  HEALTH_FACILITY         Centro de Saúde -22.811235
# 354      Nhachengue               CS         Centro de Saúde -22.855383
# 5           Macunhe  HEALTH_FACILITY         Centro de Saúde -21.898055
# 389         Macunhe               CS         Centro de Saúde -21.861967
# 6       Vialanculos  HEALTH_FACILITY         Centro de Saúde -21.992814
# 394     Vialanculos               CS         Centro de Saúde -21.992863
# 506           Darue               CS         Centro de Saúde -19.787809
# 507           Darue               CS         Centro de Saúde -19.413175
# 517        Sembezea               CS         Centro de Saúde -19.313763
# 518        Sembezea               CS         Centro de Saúde -19.415832
# 529       Chigodole               CS         Centro de Saúde -19.093097
# 530       Chigodole               CS         Centro de Saúde -18.951820
# 7        Abel Jafar  HEALTH_FACILITY         Centro de Saúde -25.065998
# 663      Abel Jafar               CS         Centro de Saúde -25.813206
# 8          Namaacha  HEALTH_FACILITY         Centro de Saúde -25.991003
# 709        Namaacha               CS         Centro de Saúde -25.991052
# 10           Nakata  HEALTH_FACILITY         Centro de Saúde -14.937582
# 762          Nakata               CS         Centro de Saúde -14.937344
# 13           Nhango  HEALTH_FACILITY         Centro de Saúde -20.191321
# 1188         Nhango               CS         Centro de Saúde -20.191229
# 1357        Militar               HM  Hospital Especializado -16.105483
# 1370        Militar               HM  Hospital Especializado -16.143706
# 16         Chissavo  HEALTH_FACILITY         Centro de Saúde -15.271722
# 1438       Chissavo               CS         Centro de Saúde -15.615812
# 18          Ualasse  HEALTH_FACILITY         Centro de Saúde -15.764290
# 1535        Ualasse               CS         Centro de Saúde -15.762120
# 19    Palane-Mucula  HEALTH_FACILITY         Centro de Saúde -17.975938
# 1543  Palane-Mucula               CS         Centro de Saúde -17.976583
# 22          Milange  HEALTH_FACILITY         Centro de Saúde -16.099654
# 1582        Milange               CS         Centro de Saúde -16.097938
# 25           Mocuba    DISTRICT_HOSP      Hospital Distrital -16.841003
# 1614         Mocuba               HD      Hospital Distrital -16.840600
# 23          Muanaco  HEALTH_FACILITY         Centro de Saúde -16.878409
# 1602        Muanaco               CS         Centro de Saúde -16.860507
# 27       Morrumbala  HEALTH_FACILITY         Centro de Saúde -17.327573
# 1653     Morrumbala               CS         Centro de Saúde -17.328020
# 28            Mbawa  HEALTH_FACILITY         Centro de Saúde -17.640142
# 1671          Mbawa               CS         Centro de Saúde -17.640093
# 29     Alto Maganha  HEALTH_FACILITY         Centro de Saúde -17.012537
# 1699   Alto Maganha               CS         Centro de Saúde -17.006389
# 30          Mihecue  HEALTH_FACILITY         Centro de Saúde -16.555418
# 1703        Mihecue               CS         Centro de Saúde -16.400483
# 31        Txalalane  HEALTH_FACILITY         Centro de Saúde -16.493294
# 1710      Txalalane               CS         Centro de Saúde -16.407263
#
#       longitude source    distance  same_source  duplicate
# 34    40.530970    PLM    0.000000         True       True
# 35    40.530970    PLM    0.000000         True      False
# 0     40.453321    ISS   19.164728        False      False
# 62    40.284900    PLM   19.164728        False      False
# 1     40.351586    ISS    0.856147        False       True
# 70    40.343966    PLM    0.856147        False      False
# 257   33.370370    PLM   34.288372         True      False
# 258   33.485300    PLM   34.288372         True      False
# 304   35.163382    PLM    0.006533         True       True
# 305   35.163350    PLM    0.006533         True      False
# 2     35.091946    ISS   18.908327        False      False
# 325   35.188847    PLM   18.908327        False      False
# 3     34.138499    ISS    0.619780        False       True
# 338   34.144018    PLM    0.619780        False      False
# 4     35.168676    ISS    4.221153        False      False
# 354   35.180460    PLM    4.221153        False      False
# 5     35.304339    ISS    6.697739        False      False
# 389   35.251801    PLM    6.697739        False      False
# 6     35.320805    ISS    0.110817        False       True
# 394   35.319809    PLM    0.110817        False      False
# 506   33.352056    PLM   35.421804         True      False
# 507   33.293041    PLM   35.421804         True      False
# 517   32.944346    PLM   39.894312         True      False
# 518   33.292790    PLM   39.894312         True      False
# 529   33.221358    PLM   14.038625         True      False
# 530   33.265839    PLM   14.038625         True      False
# 7     33.682658    ISS  134.087588        False      False
# 663   32.651664    PLM  134.087588        False      False
# 8     32.012303    ISS    0.115525        False       True
# 709   32.013341    PLM    0.115525        False      False
# 10    37.175609    ISS    0.109764        False       True
# 762   37.176578    PLM    0.109764        False      False
# 13    33.907671    ISS    0.111547        False       True
# 1188  33.908671    PLM    0.111547        False      False
# 1357  33.633727    PLM    4.630747         True      False
# 1370  33.606871    PLM    4.630747         True      False
# 16    30.404272    ISS   33.197215        False      False
# 1438  30.437275    PLM   33.197215        False      False
# 18    37.280009    ISS    0.569941        False       True
# 1535  37.284835    PLM    0.569941        False      False
# 19    36.858938    ISS    0.129758        False       True
# 1543  36.857892    PLM    0.129758        False      False
# 22    35.739104    ISS    4.745210        False      False
# 1582  35.781756    PLM    4.745210        False      False
# 25    36.986274    ISS    0.140959        False       True
# 1614  36.987500    PLM    0.140959        False      False
# 23    36.966921    ISS    2.870477        False      False
# 1602  36.988412    PLM    2.870477        False      False
# 27    35.577030    ISS    0.111667        False       True
# 1653  35.576094    PLM    0.111667        False      False
# 28    37.264693    ISS    0.764859        False       True
# 1671  37.271572    PLM    0.764859        False      False
# 29    38.719223    ISS   26.658829        False      False
# 1699  38.958923    PLM   26.658829        False      False
# 30    38.772371    ISS   23.139133        False      False
# 1703  38.603026    PLM   23.139133        False      False
# 31    38.951314    ISS    8.695634        False      False
# 1710  38.910858    PLM    8.695634        False      False

# %%
print("Number of duplicates to be dropped:", duplicates[duplicates['duplicate']].shape[0])
# Out:
# Number of duplicates to be dropped: 13

# %%
# Drop duplicates
plm_iss = pd.concat([df[~df.duplicated(subset=['admin1', 'admin2',
                          'name_short', 'type_cleaned'],
                keep=False)], duplicates[~duplicates['duplicate']][cols]],
          axis = 0)

# %%
print("Number of new ISS points added:",
     plm_iss[plm_iss['source']=='ISS'].shape[0])
# Out:
# Number of new ISS points added: 23

# %%
#plm_iss.to_csv(saveDir + '\plm_iss_0729.csv')

# %% [markdown]
# ## Adding new WHO points

# %%
plm_iss = pd.read_csv(saveDir + '\plm_iss_0729.csv')

# %%
who_new = gpd.read_file(dataDir, driver='FileGDB', 
                   layer='WHO')
who_new = who_new[cols]
who_new['admin1'] = who_new['admin1'].str.replace('Zambézia', 'Zambezia')

# %%
print("Number of new WHO points:", who_new.shape[0])
# Out:
# Number of new WHO points: 726

# %%
# combine dataframes
df = pd.concat([plm_iss,who_new], axis=0)

# %%
df.head()
# Out:
#        id   admin1               admin2          name_full      name_short  \
# 9   63664  Nampula  Distrito De Nampula  CS 25 DE SETEMBRO  25 De Setembro
# 11  63643  Nampula               Rapale          CS RAPALE          Rapale
# 12  63660   Sofala                 Buzi     CS GUARA-GUARA     Guara-Guara
# 14  63659   Sofala           Nhamatanda      CS NHARCHONGA      Nharchonga
# 15  63291     Tete               Marara    CS MUFA CACONDE    Mufa Caconde
#
#       type_original     type_cleaned   latitude  longitude source
# 9   HEALTH_FACILITY  Centro de Saúde -15.112227  39.253085    ISS
# 11  HEALTH_FACILITY  Centro de Saúde -15.025340  39.122963    ISS
# 12  HEALTH_FACILITY  Centro de Saúde -19.884094  34.593518    ISS
# 14  HEALTH_FACILITY  Centro de Saúde -19.262732  34.193562    ISS
# 15  HEALTH_FACILITY  Centro de Saúde -16.158024  33.261667    ISS

# %% [markdown]
# Since WHO dataset does not have information on `admin2`, consider rows with identical values in `admin1`, `name_short` and `type_cleaned` as duplicates.

# %%
duplicates = df[df.duplicated(subset=['admin1', 'name_short', 'type_cleaned'],
                keep=False)] \
.sort_values(['admin1', 'name_short', 'type_cleaned', 'source'])

# %%
duplicates.head(6)
# Out:
#         id        admin1           admin2                        name_full  \
# 129  HF130  Cabo Delgado        Quissanga                      PS Bilibiza
# 0    49852  Cabo Delgado             None          Bilibiza Posto de Saúde
# 33    HF34  Cabo Delgado  Cidade De Pemba                        CS Chuiba
# 1    49862  Cabo Delgado             None  Chuiba Centro de Saúde Urbano C
# 56    HF57  Cabo Delgado           Meluco                        CS Imbada
# 2    49871  Cabo Delgado             None  Imbada Centro de Saúde Rural II
#
#     name_short             type_original     type_cleaned  latitude  \
# 129   Bilibiza                        PS   Posto de Saúde  -12.5639
# 0     Bilibiza            Posto de Saúde   Posto de Saúde  -13.5795
# 33      Chuiba                        CS  Centro de Saúde  -13.0597
# 1       Chuiba  Centro de Saúde Urbano C  Centro de Saúde  -13.0225
# 56      Imbada                        CS  Centro de Saúde  -12.5430
# 2       Imbada  Centro de Saúde Rural II  Centro de Saúde  -12.3964
#
#      longitude source
# 129    40.2853    PLM
# 0      39.7356    WHO
# 33     40.5250    PLM
# 1      40.5656    WHO
# 56     39.6440    PLM
# 2      40.1075    WHO

# %%
uniques = duplicates[~duplicates.duplicated(subset=['admin1', 'name_short', 'type_cleaned'])]\
.sort_values(['admin1', 'name_short', 'type_cleaned'])

# %%
print("Number of duplicates identified for now:", uniques.shape[0])
# Out:
# Number of duplicates identified for now: 442

# %%
distances = []
dups = []
for idx, row in uniques.iterrows():
    test_df = duplicates[(duplicates['admin1'] == row['admin1']) & \
              (duplicates['name_short'] == row['name_short']) & \
              (duplicates['type_cleaned'] == row['type_cleaned'])]
    
    num = test_df.shape[0]
    
    if num == 2:
        row1 = test_df.iloc[0,:]
        row2 = test_df.iloc[1,:]
        p1 = (row1['longitude'], row1['latitude'])
        p2 = (row2['longitude'], row2['latitude'])
        dist = distance(p1,p2)
        distances.append(dist)
        distances.append(dist)
        
    if num == 3:
        row1 = test_df.iloc[0,:]
        row2 = test_df.iloc[1,:]
        row3 = test_df.iloc[2,:]
        p1 = (row1['longitude'], row1['latitude'])
        p2 = (row2['longitude'], row2['latitude'])
        p3 = (row3['longitude'], row3['latitude'])
        d12 = distance(p1, p2)
        d13 = distance(p1, p3)
        d23 = distance(p2, p3)
        distances.append(min(d12,d13))
        distances.append(min(d12,d23))
        distances.append(min(d23,d13))
duplicates['distance'] = distances

# %%
who_dups = duplicates[(duplicates['distance']<1) & (duplicates['source']=='WHO')]

# %%
print("Number of duplicates to be dropped:",
     who_dups.shape[0])
# Out:
# Number of duplicates to be dropped: 112

# %%
duplicates2 = pd.concat([duplicates,who_dups], axis=0)\
.drop_duplicates(keep=False)

# %%
final_df = pd.concat([df[~df.duplicated(subset=['admin1', 'name_short', 'type_cleaned'],
                keep=False)],duplicates2],axis=0)

# %%
#final_df.to_csv(saveDir + '/mfl_0729.csv')

# %%
print("Number of new data points added:", final_df[(final_df['source']=='WHO')| \
        (final_df['source']=='ISS')].shape[0])
print("Number of data points in total:", final_df.shape[0])
# Out:
# Number of new data points added: 637
# Number of data points in total: 2347

# %%
# province breakdown of new points
final_df[(final_df['source']=='WHO')| \
        (final_df['source']=='ISS')]['admin1'].value_counts()
# Out:
# Sofala              182
# Zambezia             98
# Nampula              80
# Niassa               48
# Tete                 47
# Maputo Provincia     45
# Inhambane            42
# Manica               30
# Gaza                 30
# Cabo Delgado         30
# Maputo Cidade         5
# Name: admin1, dtype: int64

# %%
# facility type breakdown of new points
final_df[(final_df['source']=='WHO')| \
        (final_df['source']=='ISS')]['type_cleaned'].value_counts()
# Out:
# Centro de Saúde        456
# Posto de Saúde         163
# Hospital Distrital       5
# Hospital Rurais          5
# Hospital Provincial      3
# Hospital Central         2
# Hospital Geral           2
# Other                    1
# Name: type_cleaned, dtype: int64

# %%
df = final_df[cols]
df.columns
# Out:
# Index(['id', 'admin1', 'admin2', 'name_full', 'name_short', 'type_original',
#        'type_cleaned', 'latitude', 'longitude', 'source'],
#       dtype='object')

# %%
#df.to_csv(saveDir + '/mfl_0729.csv')

# %%
df.shape
# Out:
# (2347, 10)

# %%
duplicates = df[df.duplicated(subset=['admin1', 'admin2', 'name_short', 'type_cleaned'],
                keep=False)] \
.sort_values(['admin1', 'admin2', 'name_short', 'type_cleaned', 'source'])

# %%
duplicates.shape
# Out:
# (36, 10)
