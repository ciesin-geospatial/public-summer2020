# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import os
from symspellpy import SymSpell
import time
from itertools import islice
from fuzzywuzzy import fuzz
from ordered_set import OrderedSet
from fuzzywuzzy import process

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('mode.chained_assignment', None)

# %%
# data import
dataDir = r"C:\Users\DUANYUEYUN\Documents\ArcGIS\Projects\WHO_ISS"
df_iss = gpd.read_file(dataDir+"\\WHO_ISS.gdb", driver='FileGDB', 
                       layer= 'ISS_1020')
dataDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\Cleaned"
filename = "clean_names_types_1117.csv"
path = os.path.join(dataDir, filename)
new_cols = pd.read_csv(path)

# %%
dataDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\Cleaned"
type_dict = pd.read_csv(dataDir + "//type_dict_1109.csv")

# %%
# get index
df_iss.reset_index(inplace=True)
# merge with new columns including 'clean_name_final'
df_iss = df_iss.merge(new_cols, on='index')

# %%
# obtain rows with NA in extract_type and clean_name_final has 2 words or more
sample = df_iss[(pd.isna(df_iss['extract_type']))&(df_iss['clean_name_final'].str.count(' ')>0)]

# %%
print("Number of data points:", sample.shape[0])
# Out:
# Number of data points: 24708

# %%
print("Distribution of data points by country:")
s = sample['Country'].value_counts()
s
# Out:
# Distribution of data points by country:
# NIGERIA                             14123
# DEMOCRATIC REPUBLIC OF THE CONGO     1792
# CHAD                                 1652
# MALI                                 1208
# LIBERIA                               616
# SOUTH SUDAN                           615
# MADAGASCAR                            599
# CAMEROON                              596
# GABON                                 588
# NIGER                                 390
# CONGO                                 382
# CENTRAL AFRICAN REPUBLIC              308
# ANGOLA                                256
# COTE D'IVOIRE                         215
# SENEGAL                               122
# BENIN                                 108
# EQUATORIAL GUINEA                     107
# MALAWI                                103
# SOUTH AFRICA                          103
# GHANA                                  96
# ETHIOPIA                               87
# UGANDA                                 83
# GUINEA BISSAU                          83
# GUINEA                                 73
# ESWATINI                               68
# SIERRA LEONE                           63
# TANZANIA                               58
# KENYA                                  38
# MAURITANIA                             31
# SEYCHELLES                             31
# ZIMBABWE                               29
# TOGO                                   26
# RWANDA                                 18
# MAURITIUS                               9
# BURUNDI                                 9
# ERITREA                                 7
# GAMBIA                                  7
# BOTSWANA                                4
# SAO TOME AND PRINCIPE                   4
# NAMIBIA                                 1
# Name: Country, dtype: int64

# %%
# Divide countries into 4 tiers using the number of data points
above_10k = s[s>10000].index.to_list()
btw_1k_10k = s[(s>=1000)&(s<10000)].index.to_list()
btw_100_1k = s[(s>=100)&(s<1000)].index.to_list()
under_100 = s[s<100].index.to_list()

# %%
# ignore countries with fewer than 100 data points
countries = above_10k + btw_1k_10k + btw_100_1k

# %%
# Write cleaned names into txt file
saveDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\type dict"
for country in countries:
    tmp = sample[sample['Country']==country]
    filename = country+".txt"
    file1 = open(os.path.join(saveDir, filename),"w")
    file1.write(' '.join(list(tmp['clean_name_final'].str.lower()))) 
    file1.close()

# %%
saveDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\type dict"
# generate word frequency dictionary
freq_dict = {}
for country in countries:
    sym_spell = SymSpell()
    filename = country+".txt"
    corpus_path = os.path.join(saveDir, filename)
    sym_spell.create_dictionary(corpus_path)

    d = sym_spell.words
    # sort in decreasing frequency
    sorted_d = {k: v for k, v in sorted(d.items(), key=lambda item: -item[1])}
    freq_dict[country] = sorted_d

# %%
# Example word frequency dictionary
print(list(islice(freq_dict["GABON"].items(),5)))
# Out:
# [('infirmerie', 121), ('cabinet', 84), ('07', 82), ('chr', 79), ('bele', 74)]

# %% [markdown]
# Methodology:
#
# - Select top 10 or top 20 most frequent words with at least some frequency.
# - Hand pick words that might contain type information.
# - Randomly sample rows where facility name contains the words picked in the previous step.
# - Add new rows to type dictionary if applicable.

# %% [markdown]
# # Between 100 and 10k
#
# Examine top 10 words with highest frequency and frequency > 20

# %%
cols = ['Country', 'name_of_facility_visited', 'clean_name_final', 'type_of_facility_visited']

# %%
len(btw_100_1k)
# Out:
# 15

# %%
country = btw_100_1k[0]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: LIBERIA
# Top 10 words:
# town 85
# st 40
# community 32
# medical 26
# j 25
# g 22
# francis 21

# %%
words = ['community', 'medical']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#      Country                        Type Abbreviation  count
# 189  Liberia                      Clinic       CLINIC  661.0
# 190  Liberia            General Hospital           CH    NaN
# 191  Liberia               Health Centre           HC   41.0
# 192  Liberia                    Hospital         HOSP   29.0
# 193  Liberia            Mission Hospital           MH    8.0
# 194  Liberia  National Referral Hospital          NRH    1.0

# %%
# sample 10 rows where facility name contains that word
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#        Country   name_of_facility_visited           clean_name_final  \
# 43442  LIBERIA       Cinta Town Community       Cinta Town Community
# 41461  LIBERIA              New Community              New Community
# 42044  LIBERIA           Flumpa community           Flumpa Community
# 44862  LIBERIA           Yeamei community           Yeamei Community
# 41833  LIBERIA  Weala Methodist community  Weala Methodist Community
# 44236  LIBERIA            Kaneh Community            Kaneh Community
# 42240  LIBERIA       Yarnwullif community       Yarnwullif Community
# 43545  LIBERIA           Yeamei community           Yeamei Community
# 43432  LIBERIA           Flumpa community           Flumpa Community
# 42312  LIBERIA            Weala community            Weala Community
#
#       type_of_facility_visited
# 43442               PHC_CENTER
# 41461               PHC_CENTER
# 42044               PHC_CENTER
# 44862               PHC_CENTER
# 41833               PHC_CENTER
# 44236               PHC_CENTER
# 42240               PHC_CENTER
# 43545               PHC_CENTER
# 43432               PHC_CENTER
# 42312               PHC_CENTER

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#        Country name_of_facility_visited        clean_name_final  \
# 44359  LIBERIA            Faith Medical           Faith Medical
# 41311  LIBERIA         Lukambeh medical        Lukambeh Medical
# 44571  LIBERIA             Afro medical            Afro Medical
# 44696  LIBERIA            Faith Medical           Faith Medical
# 41473  LIBERIA             Zobo Medical            Zobo Medical
# 41256  LIBERIA   Dutch Liberian Medical  Dutch Liberian Medical
# 43012  LIBERIA        All Grace Medical       All Grace Medical
# 41247  LIBERIA           Anatah Medical          Anatah Medical
# 41990  LIBERIA      12th Street Medical     12Th Street Medical
# 44275  LIBERIA         Patience medical        Patience Medical
#
#       type_of_facility_visited
# 44359          MCH_CARE_CENTER
# 41311               PHC_CENTER
# 44571               PHC_CENTER
# 44696          MCH_CARE_CENTER
# 41473               PHC_CENTER
# 41256               PHC_CENTER
# 43012               PHC_CENTER
# 41247               PHC_CENTER
# 41990               PHC_CENTER
# 44275               PHC_CENTER

# %%
country = btw_100_1k[1]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: SOUTH SUDAN
# Top 10 words:
# poc 164
# clinic 151
# sector 124
# iom 101
# malakal 97
# imc 73
# aa 59
# 2 55
# 1 46
# mayen 45

# %%
words = ['poc', 'clinic', 'iom', 'imc']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#          Country                        Type Abbreviation   count
# 333  South Sudan             County Hospital           CH    28.0
# 334  South Sudan                    Hospital         HOSP     NaN
# 335  South Sudan  Primary Health Care Centre         PHCC   332.0
# 336  South Sudan    Primary Health Care Unit         PHCU  1375.0
# 337  South Sudan              State Hospital           SH     9.0
# 338  South Sudan           Teaching Hospital           TH     3.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#             Country  name_of_facility_visited          clean_name_final  \
# 292604  SOUTH SUDAN        Poc AA  IOM Clinic         Poc Aa Iom Clinic
# 292031  SOUTH SUDAN         POC AA IMC clinic         Poc Aa Imc Clinic
# 293017  SOUTH SUDAN        Poc AA  IOM Clinic         Poc Aa Iom Clinic
# 293753  SOUTH SUDAN  Malakal POC Sector 1 IMC  Malakal Poc Sector 1 Imc
# 293135  SOUTH SUDAN  Malakal POC Sector 1 IMC  Malakal Poc Sector 1 Imc
# 293013  SOUTH SUDAN         POC AA IMC clinic         Poc Aa Imc Clinic
# 292505  SOUTH SUDAN        Poc AA  IOM Clinic         Poc Aa Iom Clinic
# 293300  SOUTH SUDAN        Poc AA  IOM Clinic         Poc Aa Iom Clinic
# 293495  SOUTH SUDAN  Malakal POC Sector 2 IOM  Malakal Poc Sector 2 Iom
# 293227  SOUTH SUDAN         POC AA IMC clinic         Poc Aa Imc Clinic
#
#        type_of_facility_visited
# 292604                     PHCC
# 292031                     PHCC
# 293017                     PHCC
# 293753                     PHCC
# 293135                     PHCC
# 293013                     PHCC
# 292505                     PHCC
# 293300                     PHCC
# 293495                     PHCC
# 293227                     PHCC

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#             Country name_of_facility_visited         clean_name_final  \
# 292557  SOUTH SUDAN       Poc AA  IOM Clinic        Poc Aa Iom Clinic
# 293055  SOUTH SUDAN   Mandeng private clinic   Mandeng Private Clinic
# 292787  SOUTH SUDAN    Bahr El Ghazal Clinic    Bahr El Ghazal Clinic
# 292558  SOUTH SUDAN    Bahr El Ghazal Clinic    Bahr El Ghazal Clinic
# 293266  SOUTH SUDAN        POC AA IMC clinic        Poc Aa Imc Clinic
# 291090  SOUTH SUDAN  Tuochriak Mobile Clinic  Tuochriak Mobile Clinic
# 292520  SOUTH SUDAN               Rom clinic               Rom Clinic
# 291687  SOUTH SUDAN       Poc AA  IOM Clinic        Poc Aa Iom Clinic
# 292291  SOUTH SUDAN     Abiemnom Life Clinic     Abiemnom Life Clinic
# 293410  SOUTH SUDAN       Poc AA  IOM Clinic        Poc Aa Iom Clinic
#
#        type_of_facility_visited
# 292557                     PHCC
# 293055         PRIVATE_FACILITY
# 292787         PRIVATE_FACILITY
# 292558         PRIVATE_FACILITY
# 293266                     PHCC
# 291090                     PHCU
# 292520         PRIVATE_FACILITY
# 291687                     PHCC
# 292291         PRIVATE_FACILITY
# 293410                     PHCC

# %%
country = btw_100_1k[2]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: MADAGASCAR
# Top 10 words:
# sud 63
# i 46
# ville 45
# tsiroanomandidy 37
# tanambao 29
# nord 26
# anosibe 26
# an 26
# ala 26
# soanierana 25

# %%
words = ['sud']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#         Country                    Type Abbreviation   count
# 195  Madagascar   Basic Health Center I         CSB1     NaN
# 196  Madagascar  Basic Health Center II         CSB2     NaN
# 197  Madagascar       District Hospital         CHD1     NaN
# 198  Madagascar           Health Centre           HC  1642.0
# 199  Madagascar             Health Post           HP   910.0
# 200  Madagascar                Hospital         HOSP   125.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#           Country name_of_facility_visited     clean_name_final  \
# 46907  MADAGASCAR             ANDILANA SUD         Andilana Sud
# 47529  MADAGASCAR             MAROVOAY SUD         Marovoay Sud
# 47855  MADAGASCAR            ANKAZOABO SUD        Ankazoabo Sud
# 47776  MADAGASCAR              BETIOKY SUD          Betioky Sud
# 47532  MADAGASCAR             MAROVOAY SUD         Marovoay Sud
# 46714  MADAGASCAR           MANAMBOTRA SUD       Manambotra Sud
# 47961  MADAGASCAR            AMBOASARY SUD        Amboasary Sud
# 48563  MADAGASCAR          SAHANIVOTRY SUD      Sahanivotry Sud
# 48478  MADAGASCAR      CHRDI AMBOASARY SUD  Chrdi Amboasary Sud
# 45498  MADAGASCAR          ANDREBAKELY SUD      Andrebakely Sud
#
#       type_of_facility_visited
# 46907   Basic_Health_Center_II
# 47529   Basic_Health_Center_II
# 47855   Basic_Health_Center_II
# 47776   Basic_Health_Center_II
# 47532   Basic_Health_Center_II
# 46714   Basic_Health_Center_II
# 47961   Basic_Health_Center_II
# 48563   Basic_Health_Center_II
# 48478            DISTRICT_HOSP
# 45498   Basic_Health_Center_II

# %%
country = btw_100_1k[3]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: CAMEROON
# Top 10 words:
# cm 96
# csc 75
# csp 62
# cabinet 51
# soins 43
# la 33
# fondation 32
# csiu 28
# ebolowa 28
# catholique 23

# %%
words = ['cm', 'csc', 'csp', 'cabinet', 'csiu']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#      Country                             Type Abbreviation   count
# 42  Cameroon  Centre Medical d'Arrondissement          CMA   223.0
# 43  Cameroon                  Centre de Sante           CS     NaN
# 44  Cameroon          Centre de Sante Integre          CSI  2241.0
# 45  Cameroon                           Clinic       CLINIC     3.0
# 46  Cameroon                       Dispensary         DISP    48.0
# 47  Cameroon                    Health Centre           HC   362.0
# 48  Cameroon                         Hospital         HOSP     NaN
# 49  Cameroon                Hospital Centraux        HOSPC     2.0
# 50  Cameroon                 Hospital General           HG     3.0
# 51  Cameroon                Hospital Regional           HR    14.0
# 52  Cameroon             Hospital de District           HD   165.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#         Country    name_of_facility_visited            clean_name_final  \
# 7160   CAMEROON                 CM SOSUCAM1                 Cm Sosucam1
# 9514   CAMEROON                 Cm Sosucam2                 Cm Sosucam2
# 7268   CAMEROON                    CMS/CNPS                    Cms Cnps
# 9283   CAMEROON                 CM SOSUCAM1                 Cm Sosucam1
# 9175   CAMEROON  CME Fondation Chantal Biya  Cme Fondation Chantal Biya
# 7000   CAMEROON              Cm Escadron 14              Cm Escadron 14
# 7712   CAMEROON                 Cm Baptiste                 Cm Baptiste
# 12137  CAMEROON            CM La Passerelle            Cm La Passerelle
# 8018   CAMEROON   CM Notre Dame de la Merci      Cm Notre Dame La Merci
# 11976  CAMEROON                 CM SOSUCAM1                 Cm Sosucam1
#
#       type_of_facility_visited
# 7160          PRIVATE_FACILITY
# 9514          PRIVATE_FACILITY
# 7268          PRIVATE_FACILITY
# 9283          PRIVATE_FACILITY
# 9175             TEACHING_HOSP
# 7000                  MILITARY
# 7712          PRIVATE_FACILITY
# 12137                      CMA
# 8018          PRIVATE_FACILITY
# 11976         PRIVATE_FACILITY

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#         Country name_of_facility_visited clean_name_final  \
# 7818   CAMEROON            CSC de Dimako       Csc Dimako
# 11545  CAMEROON              Csc Ndelele      Csc Ndelele
# 6101   CAMEROON             CSC de Letta        Csc Letta
# 7904   CAMEROON          CSC Abong-Mbang  Csc Abong Mbang
# 8131   CAMEROON           CSC de Borongo      Csc Borongo
# 10835  CAMEROON             CSC de Guili        Csc Guili
# 11698  CAMEROON               CSC MVOLYE       Csc Mvolye
# 12368  CAMEROON          CSC elat-Minkom  Csc Elat Minkom
# 11296  CAMEROON            CSC Yokadouma    Csc Yokadouma
# 8904   CAMEROON          CSC elat-Minkom  Csc Elat Minkom
#
#       type_of_facility_visited
# 7818                       CSI
# 11545                      CSI
# 6101               FAITH_BASED
# 7904               FAITH_BASED
# 8131                       CSI
# 10835                      CSI
# 11698              FAITH_BASED
# 12368              FAITH_BASED
# 11296                      CSI
# 8904               FAITH_BASED

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[2], case=False))][cols].sample(10)
# Out:
#         Country          name_of_facility_visited  \
# 5482   CAMEROON  CSP Catholique Mayo-Darle (cnls)
# 7877   CAMEROON                       CSP Bessaye
# 12602  CAMEROON             CSP Baptiste Nyamboya
# 11891  CAMEROON                         CSPP Dang
# 6087   CAMEROON                       CSP le bien
# 7710   CAMEROON                       CSP Bessaye
# 6246   CAMEROON                     CSP Islamique
# 7770   CAMEROON   CSP la Compassion (CSP Ndokayo)
# 11964  CAMEROON                   CSP Afanetouana
# 11199  CAMEROON             CSP Baptiste Nyamboya
#
#                      clean_name_final type_of_facility_visited
# 5482   Csp Catholique Mayo Darle Cnls              FAITH_BASED
# 7877                      Csp Bessaye         PRIVATE_FACILITY
# 12602           Csp Baptiste Nyamboya              FAITH_BASED
# 11891                       Cspp Dang              FAITH_BASED
# 6087                      Csp Le Bien         PRIVATE_FACILITY
# 7710                      Csp Bessaye         PRIVATE_FACILITY
# 6246                    Csp Islamique                      CSI
# 7770    Csp La Compassion Csp Ndokayo         PRIVATE_FACILITY
# 11964                 Csp Afanetouana         PRIVATE_FACILITY
# 11199           Csp Baptiste Nyamboya              FAITH_BASED

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[3], case=False))][cols].sample(10)
# Out:
#         Country                 name_of_facility_visited  \
# 6128   CAMEROON          Cabinet de Soins le Bon secours
# 5911   CAMEROON       Cabinet de soin de  Bon Samaritain
# 12348  CAMEROON                 Cabinet de Soins Acacias
# 9191   CAMEROON       Cabinet de soins St Etienne (cnls)
# 12676  CAMEROON  Cabinet Medico-sanitaire LA BENEDICTION
# 5134   CAMEROON            Cabinet de Soins Grace Divine
# 6664   CAMEROON                Cabinet De Soins La Grace
# 12339  CAMEROON   Cabinet de Soins Notre Dame du Rosaire
# 12351  CAMEROON   Cabinet de Soins Notre Dame du Rosaire
# 11469  CAMEROON              Cabinet Soins La Solidarite
#
#                               clean_name_final type_of_facility_visited
# 6128              Cabinet Soins Le Bon Secours         PRIVATE_FACILITY
# 5911               Cabinet Soin Bon Samaritain         PRIVATE_FACILITY
# 12348                    Cabinet Soins Acacias         PRIVATE_FACILITY
# 9191             Cabinet Soins St Etienne Cnls         PRIVATE_FACILITY
# 12676  Cabinet Medico Sanitaire La Benediction         PRIVATE_FACILITY
# 5134                Cabinet Soins Grace Divine                      CSI
# 6664                    Cabinet Soins La Grace         PRIVATE_FACILITY
# 12339         Cabinet Soins Notre Dame Rosaire              FAITH_BASED
# 12351         Cabinet Soins Notre Dame Rosaire              FAITH_BASED
# 11469              Cabinet Soins La Solidarite         PRIVATE_FACILITY

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[4], case=False))][cols].sample(10)
# Out:
#         Country name_of_facility_visited    clean_name_final  \
# 5613   CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 8619   CAMEROON         CSIU N°2 Ebolowa  Csiu Ndeg2 Ebolowa
# 10713  CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 10188  CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 5727   CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 10131  CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 10186  CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 5645   CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 5679   CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
# 5639   CAMEROON         CSIU N°1 Ebolowa  Csiu Ndeg1 Ebolowa
#
#       type_of_facility_visited
# 5613                       CSI
# 8619                       CSI
# 10713                      CSI
# 10188                      CSI
# 5727                       CSI
# 10131                      CSI
# 10186                      CSI
# 5645                       CSI
# 5679                       CSI
# 5639                       CSI

# %%
country = btw_100_1k[4]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: GABON
# Top 10 words:
# infirmerie 121
# cabinet 84
# 07 82
# chr 79
# bele 74
# port 72
# gentil 72
# la 49
# lycee 40
# base 32

# %%
words = ['infirmerie', 'cabinet', 'chr']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#     Country                      Type Abbreviation  count
# 132   Gabon  Centre Hospitalier Urban          CHU    1.0
# 133   Gabon           Centre de Sante           CS    NaN
# 134   Gabon     Centre de Sante Urban          CSU    4.0
# 135   Gabon                    Clinic       CLINIC    NaN
# 136   Gabon                Dispensary         DISP  387.0
# 137   Gabon             Health Centre           HC   92.0
# 138   Gabon                  Hospital         HOSP    NaN
# 139   Gabon      Hospital Cooperation        HOSPC    3.0
# 140   Gabon            Medical Centre           MC   43.0
# 141   Gabon                Polyclinic      PCLINIC    NaN
# 142   Gabon         Regional Hospital           RH   10.0
# 143   Gabon       University Hospital           UH    2.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#       Country                           name_of_facility_visited  \
# 30492   GABON         Infirmerie Lycée General Nazaire Boulingui
# 31688   GABON                               Infirmerie de la CEB
# 30596   GABON                              Infirmerie de la gare
# 32140   GABON                              Infirmerie de la gare
# 32988   GABON                               Infirmerie de la CEB
# 31173   GABON                               Infirmerie de la CEB
# 32352   GABON      Infirmerie de la prison centrale de Tchibanga
# 31761   GABON                             Infirmerie 7eme region
# 31481   GABON  Infirmerie Lycée Horizon de La Mission Catholique
# 31714   GABON              Infirmerie du lycée publique François
#
#                                      clean_name_final type_of_facility_visited
# 30492      Infirmerie Lycee General Nazaire Boulingui                      CSI
# 31688                               Infirmerie La Ceb         PRIVATE_FACILITY
# 30596                              Infirmerie La Gare         PRIVATE_FACILITY
# 32140                              Infirmerie La Gare         PRIVATE_FACILITY
# 32988                               Infirmerie La Ceb         PRIVATE_FACILITY
# 31173                               Infirmerie La Ceb         PRIVATE_FACILITY
# 32352         Infirmerie La Prison Centrale Tchibanga                      CSI
# 31761                          Infirmerie 7Eme Region                 MILITARY
# 31481  Infirmerie Lycee Horizon La Mission Catholique                      CSI
# 31714              Infirmerie Lycee Publique Francois         PRIVATE_FACILITY

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#       Country              name_of_facility_visited  \
# 31125   GABON  Cabinet de kinésithérapie Mbouassing
# 31777   GABON               Cabinet Sainte Paulette
# 31774   GABON           Cabinet de soins Misercirde
# 31574   GABON               Cabinet Sainte Paulette
# 32244   GABON                         Cabinet Mbolo
# 31396   GABON               Cabinet Sainte Paulette
# 32129   GABON                     Cabinet de Groupe
# 31512   GABON                     Cabinet de Groupe
# 32333   GABON          Cabinet de soins miséricorde
# 30602   GABON                        Cabinet espoir
#
#                         clean_name_final type_of_facility_visited
# 31125  Cabinet Kinesitherapie Mbouassing           KINESITHERAPIE
# 31777            Cabinet Sainte Paulette         PRIVATE_FACILITY
# 31774           Cabinet Soins Misercirde         PRIVATE_FACILITY
# 31574            Cabinet Sainte Paulette         PRIVATE_FACILITY
# 32244                      Cabinet Mbolo         PRIVATE_FACILITY
# 31396            Cabinet Sainte Paulette         PRIVATE_FACILITY
# 32129                     Cabinet Groupe         PRIVATE_FACILITY
# 31512                     Cabinet Groupe         PRIVATE_FACILITY
# 32333          Cabinet Soins Misericorde         PRIVATE_FACILITY
# 30602                     Cabinet Espoir         PRIVATE_FACILITY

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[2], case=False))][cols].sample(10)
# Out:
#       Country name_of_facility_visited   clean_name_final  \
# 33242   GABON          CHR Port-Gentil    Chr Port Gentil
# 33594   GABON     CHRPM de Koulamoutou  Chrpm Koulamoutou
# 32872   GABON          CHR Port-Gentil    Chr Port Gentil
# 33473   GABON          CHR Port-Gentil    Chr Port Gentil
# 33235   GABON          CHR Port-Gentil    Chr Port Gentil
# 33258   GABON               SMI CHRGRL         Smi Chrgrl
# 33525   GABON          CHR Port-Gentil    Chr Port Gentil
# 33545   GABON          CHR Port-Gentil    Chr Port Gentil
# 33476   GABON          CHR Port-Gentil    Chr Port Gentil
# 33579   GABON          CHR Port-Gentil    Chr Port Gentil
#
#       type_of_facility_visited
# 33242               STATE_HOSP
# 33594               STATE_HOSP
# 32872               STATE_HOSP
# 33473               STATE_HOSP
# 33235               STATE_HOSP
# 33258               STATE_HOSP
# 33525               STATE_HOSP
# 33545               STATE_HOSP
# 33476               STATE_HOSP
# 33579               STATE_HOSP

# %%
country = btw_100_1k[5]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: NIGER
# Top 10 words:
# n 46
# case 40
# sante 34

# %%
words = ['case', 'sante']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#     Country                              Type Abbreviation   count
# 250   Niger  Centre Hospitalier Universitaire          CHU     1.0
# 251   Niger                        Health Hut           HH  2009.0
# 252   Niger                          Hospital         HOSP    40.0
# 253   Niger          Integrated Health Centre          CSI   836.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#       Country           name_of_facility_visited             clean_name_final  \
# 64103   NIGER                      CASE DE SANTÉ                   Case Sante
# 63773   NIGER  Case de Sante de Boulongou Yaskou  Case Sante Boulongou Yaskou
# 64967   NIGER              Case de Santé  ANIELE            Case Sante Aniele
# 64982   NIGER             case de santé  Abalama           Case Sante Abalama
# 65260   NIGER                 Case de oudi peulh              Case Oudi Peulh
# 63847   NIGER        Case de santé d' Oudi peulh      Case Sante D Oudi Peulh
# 65311   NIGER                      Case de santé                   Case Sante
# 63825   NIGER          CASE DE SANTÉ DE BONEGRAL          Case Sante Bonegral
# 63794   NIGER          CASE DE SANTÉ DE N'GAGALA          Case Sante N Gagala
# 65205   NIGER              CASE DE SANTE LAZARET           Case Sante Lazaret
#
#       type_of_facility_visited
# 64103                      CSI
# 63773                      CSI
# 64967                      CSI
# 64982                      CSI
# 65260                      CSI
# 63847   OTHER_NON_ORTHORDOX_HC
# 65311   OTHER_NON_ORTHORDOX_HC
# 63825                      CSI
# 63794                      CSI
# 65205                      CSI

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#       Country     name_of_facility_visited         clean_name_final  \
# 63671   NIGER     CASE DE SANTE KORTINIRGA    Case Sante Kortinirga
# 65455   NIGER           CASE DE SANTÉ KAWA          Case Sante Kawa
# 65205   NIGER        CASE DE SANTE LAZARET       Case Sante Lazaret
# 64967   NIGER        Case de Santé  ANIELE        Case Sante Aniele
# 63816   NIGER       CASE DE SANTE BONEGRAL      Case Sante Bonegral
# 64947   NIGER        Case de Santé  ANIELE        Case Sante Aniele
# 64982   NIGER       case de santé  Abalama       Case Sante Abalama
# 63793   NIGER   CASE DE SANTÉ DE BIRZOWEYA     Case Sante Birzoweya
# 63847   NIGER  Case de santé d' Oudi peulh  Case Sante D Oudi Peulh
# 64103   NIGER                CASE DE SANTÉ               Case Sante
#
#       type_of_facility_visited
# 63671                      CSI
# 65455                      CSI
# 65205                      CSI
# 64967                      CSI
# 63816                      CSI
# 64947                      CSI
# 64982                      CSI
# 63793                      CSI
# 63847   OTHER_NON_ORTHORDOX_HC
# 64103                      CSI

# %%
country = btw_100_1k[6]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: CONGO
# Top 10 words:
# cabinet 67
# cms 52
# soins 48
# clinic 31
# la 24

# %%
words = ['cabinet', 'cms', 'clinic']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#    Country                     Type Abbreviation  count
# 80   Congo  Centre de Sante Integre          CSI  302.0
# 81   Congo                 Hospital         HOSP    2.0
# 82   Congo     Hospital Comboutique           HC    9.0
# 83   Congo         Hospital General           HG    4.0
# 84   Congo           Poste de Sante           PS    NaN
# 85   Congo      University Hospital           UH    1.0
# 86   Congo       l'Hospital de Base           HB   10.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#       Country                      name_of_facility_visited  \
# 24818   CONGO                       CABINET DE SOINS MAKALÉ
# 25007   CONGO                             Cabinet le Berger
# 24932   CONGO  Cabinet de soins oeil SUNDI LOUTETE  Bouansa
# 25078   CONGO                    Cabinet de soins la gloire
# 24675   CONGO                Cabinet de soins Louis Merieux
# 25540   CONGO                     Cabinet De Soins La Grace
# 25253   CONGO             CABINET DE SOINS JAPOLEON KINDELE
# 24598   CONGO                         Cabinet de soins Caba
# 25012   CONGO                        Cabinet Maman Nsadissa
# 25011   CONGO                               Cabinet kiniadi
#
#                                clean_name_final type_of_facility_visited
# 24818                      Cabinet Soins Makale         PRIVATE_FACILITY
# 25007                         Cabinet Le Berger         PRIVATE_FACILITY
# 24932  Cabinet Soins Oeil Sundi Loutete Bouansa         PRIVATE_FACILITY
# 25078                   Cabinet Soins La Gloire         PRIVATE_FACILITY
# 24675               Cabinet Soins Louis Merieux         PRIVATE_FACILITY
# 25540                    Cabinet Soins La Grace         PRIVATE_FACILITY
# 25253            Cabinet Soins Japoleon Kindele         PRIVATE_FACILITY
# 24598                        Cabinet Soins Caba         PRIVATE_FACILITY
# 25012                    Cabinet Maman Nsadissa         PRIVATE_FACILITY
# 25011                           Cabinet Kiniadi         PRIVATE_FACILITY

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#       Country name_of_facility_visited         clean_name_final  \
# 25965   CONGO            Cms municipal            Cms Municipal
# 25820   CONGO            Cms municipal            Cms Municipal
# 25283   CONGO         Cms Asv patience         Cms Asv Patience
# 25084   CONGO            Cms islamique            Cms Islamique
# 25008   CONGO                Cms A.P.B                Cms A P B
# 25332   CONGO               CMS MOKABI               Cms Mokabi
# 25221   CONGO  Cms soeur Martin ouenze  Cms Soeur Martin Ouenze
# 24726   CONGO      CMS  seour Martin 2       Cms Seour Martin 2
# 25248   CONGO        CMS Soeur  Martin         Cms Soeur Martin
# 24697   CONGO               CMS Elikia               Cms Elikia
#
#       type_of_facility_visited
# 25965                      CSI
# 25820                      CSI
# 25283                      CMA
# 25084                      CMA
# 25008                      CMA
# 25332         PRIVATE_FACILITY
# 25221                      CMA
# 24726                      CSI
# 25248                      CSI
# 24697                      CMA

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[2], case=False))][cols].sample(10)
# Out:
#       Country           name_of_facility_visited  \
# 25562   CONGO                 Clinique Moungondo
# 26009   CONGO              Clinique les oliviers
# 25547   CONGO  CLINIQUE MÉDICALE MOUNGONDO NKAYI
# 25116   CONGO          Shaty clinique EL-shaddaï
# 25023   CONGO          Shaty clinique EL-shaddaï
# 25255   CONGO             Clinique Albert LEYONO
# 25315   CONGO                    Clinique Élikia
# 24845   CONGO                      Clinic leyono
# 25382   CONGO                 Clinique Moungondo
# 24609   CONGO                   Clinique securex
#
#                       clean_name_final type_of_facility_visited
# 25562                 Clinic Moungondo         PRIVATE_FACILITY
# 26009              Clinic Les Oliviers         PRIVATE_FACILITY
# 25547  Clinic Medicale Moungondo Nkayi         PRIVATE_FACILITY
# 25116          Shaty Clinic El Shaddai                      CMA
# 25023          Shaty Clinic El Shaddai                      CMA
# 25255             Clinic Albert Leyono            DISTRICT_HOSP
# 25315                    Clinic Elikia         PRIVATE_FACILITY
# 24845                    Clinic Leyono            DISTRICT_HOSP
# 25382                 Clinic Moungondo         PRIVATE_FACILITY
# 24609                   Clinic Securex         PRIVATE_FACILITY

# %%
country = btw_100_1k[7]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: CENTRAL AFRICAN REPUBLIC
# Top 10 words:
# csu 80

# %%
words = ['csu']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#                      Country                             Type Abbreviation  \
# 57  Central African Republic                  Centre de Sante           CS
# 58  Central African Republic              Centre de Sante "A"          CSA
# 59  Central African Republic              Centre de Sante "B"          CSB
# 60  Central African Republic              Centre de Sante "C"          CSC
# 61  Central African Republic              Centre de Sante "D"          CSD
# 62  Central African Republic              Centre de Sante "E"          CSE
# 63  Central African Republic                Hospital Centraux           HC
# 64  Central African Republic                Hospital District           HD
# 65  Central African Republic            Hospital Prefectoraux           HP
# 66  Central African Republic  Hospital Regional Universitaire          HRU
# 67  Central African Republic                   Poste de Sante           PS
#
#     count
# 57    2.0
# 58   43.0
# 59   44.0
# 60   57.0
# 61    2.0
# 62   61.0
# 63    3.0
# 64    NaN
# 65   12.0
# 66    5.0
# 67  326.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#                         Country name_of_facility_visited clean_name_final  \
# 13965  CENTRAL AFRICAN REPUBLIC             CSU MALIMAKA     Csu Malimaka
# 13818  CENTRAL AFRICAN REPUBLIC           CSU DE KOUALLO      Csu Kouallo
# 13968  CENTRAL AFRICAN REPUBLIC               CSU CASTOR       Csu Castor
# 13971  CENTRAL AFRICAN REPUBLIC              Csu castors      Csu Castors
# 13418  CENTRAL AFRICAN REPUBLIC               CSU TOKOYO       Csu Tokoyo
# 14328  CENTRAL AFRICAN REPUBLIC              CSU GOBONGO      Csu Gobongo
# 13247  CENTRAL AFRICAN REPUBLIC               CSU YAPELE       Csu Yapele
# 14270  CENTRAL AFRICAN REPUBLIC         CSU DE Lakouanga    Csu Lakouanga
# 13957  CENTRAL AFRICAN REPUBLIC               CSU PETEVO       Csu Petevo
# 14274  CENTRAL AFRICAN REPUBLIC               CSU PETEVO       Csu Petevo
#
#       type_of_facility_visited
# 13965                      CSI
# 13818                      CSI
# 13968                      CSI
# 13971                      CSI
# 13418                      CSI
# 14328                      CSI
# 13247                      CSI
# 14270                      CSI
# 13957                      CSI
# 14274                      CSI

# %%
country = btw_100_1k[8]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: ANGOLA
# Top 10 words:
# comuna 31
# sede 23

# %%
words = ['comuna', 'sede']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#   Country                               Type Abbreviation   count
# 0  Angola                   Central Hospital           CH     3.0
# 1  Angola            Centro Materno Infantil          CMI    39.0
# 2  Angola  Centro Sanatorio Materno Infantil         CSMI     3.0
# 3  Angola                    Centro de Saude           CS   231.0
# 4  Angola                   General Hospital           GH     3.0
# 5  Angola                           Hospital         HOSP    32.0
# 6  Angola                 Municipal Hospital           MH   100.0
# 7  Angola                     Posto de Saude           PS  1152.0
# 8  Angola                Provincial Hospital           PH    11.0
# 9  Angola                  Regional Hospital           RH     1.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#      Country   name_of_facility_visited        clean_name_final  \
# 1228  ANGOLA              Comuna Kaholo           Comuna Kaholo
# 2937  ANGOLA       COMUNA Sede Luvango.     Comuna Sede Luvango
# 1652  ANGOLA                Comuna sede             Comuna Sede
# 2943  ANGOLA           COMUNA Capelongo        Comuna Capelongo
# 2877  ANGOLA               Comuna Hoque            Comuna Hoque
# 2152  ANGOLA            Comuna da Huila            Comuna Huila
# 2878  ANGOLA               Comuna Hoque            Comuna Hoque
# 2170  ANGOLA  Comuna sede vila da Paula  Comuna Sede Vila Paula
# 995   ANGOLA           Comuna de Luvaka           Comuna Luvaka
# 2966  ANGOLA                Comuna sede             Comuna Sede
#
#      type_of_facility_visited
# 1228   OTHER_NON_ORTHORDOX_HC
# 2937                      CSI
# 1652                      CSI
# 2943            DISTRICT_HOSP
# 2877                      CSI
# 2152                      CSI
# 2878                      CSI
# 2170                      CSI
# 995                       CSI
# 2966                      CSI

# %%
country = btw_100_1k[9]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: COTE D'IVOIRE
# Top 10 words:
# dr 45
# fsu 29
# pmi 26
# com 21

# %%
words = ['fsu', 'pmi', 'com']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#           Country                       Type Abbreviation   count
# 87  Cote d'Ivoire       Centre Medico-Social          CMS    33.0
# 88  Cote d'Ivoire      Centre de Sante Rural          CSR  1330.0
# 89  Cote d'Ivoire      Centre de Sante Urban          CSU   329.0
# 90  Cote d'Ivoire           Hospital General           HG    77.0
# 91  Cote d'Ivoire       Hospitalier Regional           HR    19.0
# 92  Cote d'Ivoire  Hospitalier Universitaire           HU     4.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#              Country name_of_facility_visited      clean_name_final  \
# 26585  COTE D'IVOIRE            FSU TANGUELAN         Fsu Tanguelan
# 26358  COTE D'IVOIRE            FSU COM GESCO         Fsu Com Gesco
# 26877  COTE D'IVOIRE            FSU COM KOUTE         Fsu Com Koute
# 26883  COTE D'IVOIRE      FSU COM NIANGON SUD   Fsu Com Niangon Sud
# 27021  COTE D'IVOIRE      FSU COM VRIDI CANAL   Fsu Com Vridi Canal
# 27006  COTE D'IVOIRE     Fsu com Abobo Baoulé  Fsu Com Abobo Baoule
# 26941  COTE D'IVOIRE             FSUCOM KOUTE          Fsucom Koute
# 26873  COTE D'IVOIRE       FSU COM TOIT ROUGE    Fsu Com Toit Rouge
# 26580  COTE D'IVOIRE            FSU 22O LOGTS         Fsu 22O Logts
# 26955  COTE D'IVOIRE        FSU 220 logements     Fsu 220 Logements
#
#       type_of_facility_visited
# 26585                      CSI
# 26358                      CSI
# 26877                      CSI
# 26883                      CSI
# 27021                      CSI
# 27006                      CSI
# 26941                      CSI
# 26873                      CSI
# 26580            DISTRICT_HOSP
# 26955                      CSI

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#              Country name_of_facility_visited clean_name_final  \
# 26198  COTE D'IVOIRE               PMI SINFRA       Pmi Sinfra
# 26339  COTE D'IVOIRE                PMI Touba        Pmi Touba
# 26855  COTE D'IVOIRE               PMI GAGNOA       Pmi Gagnoa
# 26862  COTE D'IVOIRE                 PMI OUMÉ         Pmi Oume
# 26404  COTE D'IVOIRE                PMI DALOA        Pmi Daloa
# 26481  COTE D'IVOIRE               PMI Bardot       Pmi Bardot
# 26394  COTE D'IVOIRE              PMI ABOISSO      Pmi Aboisso
# 26531  COTE D'IVOIRE                PMI Ferke        Pmi Ferke
# 26317  COTE D'IVOIRE              PMI Korhogo      Pmi Korhogo
# 26694  COTE D'IVOIRE           PMI ABENGOUROU   Pmi Abengourou
#
#       type_of_facility_visited
# 26198                      CSI
# 26339               STATE_HOSP
# 26855                      CSI
# 26862                      CSI
# 26404                      CSI
# 26481                      CSI
# 26394                      CSI
# 26531            DISTRICT_HOSP
# 26317                      CSI
# 26694                      CSI

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[2], case=False))][cols].sample(10)
# Out:
#              Country name_of_facility_visited        clean_name_final  \
# 26875  COTE D'IVOIRE           FSU COM KOWEÏT          Fsu Com Koweit
# 27014  COTE D'IVOIRE      Fsu com adioposoume     Fsu Com Adioposoume
# 26872  COTE D'IVOIRE       FSU COM OUASSAKARA      Fsu Com Ouassakara
# 26237  COTE D'IVOIRE         FSUCOM TOI ROUGE        Fsucom Toi Rouge
# 26987  COTE D'IVOIRE   FSU COM ANONKOUA KOUTE  Fsu Com Anonkoua Koute
# 26494  COTE D'IVOIRE            FSU Com SAGBE           Fsu Com Sagbe
# 26941  COTE D'IVOIRE             FSUCOM KOUTE            Fsucom Koute
# 26883  COTE D'IVOIRE      FSU COM NIANGON SUD     Fsu Com Niangon Sud
# 26989  COTE D'IVOIRE   FSU COM ANONKOUA KOUTE  Fsu Com Anonkoua Koute
# 26676  COTE D'IVOIRE      FSU COM Abobo Sagbé     Fsu Com Abobo Sagbe
#
#       type_of_facility_visited
# 26875                      CSI
# 27014                      CSI
# 26872                      CSI
# 26237                      CSI
# 26987              FAITH_BASED
# 26494         PRIVATE_FACILITY
# 26941                      CSI
# 26883                      CSI
# 26989              FAITH_BASED
# 26676         PRIVATE_FACILITY

# %%
country = btw_100_1k[10]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: SENEGAL
# Top 10 words:

# %%
country = btw_100_1k[11]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: BENIN
# Top 10 words:
# cabinet 25

# %%
words = ['cabinet']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#    Country                                       Type Abbreviation  count
# 10   Benin           Centre Hospitalier Departemental          CHD    5.0
# 11   Benin                             Centre Medical           CM   24.0
# 12   Benin                       Centre Medico-Social          CMS    3.0
# 13   Benin  Centre National Hospitalier Universitaire         CNHU    2.0
# 14   Benin                            Centre de Sante           CS    NaN
# 15   Benin                    Centre de Sante Central          CSC   11.0
# 16   Benin           Centre de Sante d'Arrondissement          CSA  306.0
# 17   Benin         Centre de Sante de Sous-Prefecture         CSSP    8.0
# 18   Benin  Centro de Sante de Circonscription Urbane         CSCU    1.0
# 19   Benin                                     Clinic       CLINIC    4.0
# 20   Benin                    Community Health Centre          CHC  132.0
# 21   Benin                                 Dispensary         DISP   27.0
# 22   Benin                              Health Centre           HC  246.0
# 23   Benin                                   Hospital         HOSP   20.0
# 24   Benin                           Hospital de Zone           HZ   21.0
# 25   Benin                 Unites de Sante de Village          USV    9.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#      Country                 name_of_facility_visited  \
# 2996   BENIN           Cabinet de soins privé aafiana
# 2993   BENIN  CABINET DE SOINS LA GLOIRE/ONG ENTRAIDE
# 3281   BENIN                          Cabinet HOZIANA
# 3286   BENIN                Cabinet de Soins ENTRAIDE
# 3295   BENIN            Cabinet de soins la tolérance
# 3268   BENIN    CABINET DE SOINS INFIRMIERS DE KOKOBE
# 3301   BENIN                CABINET DE SOINS BEKAKOUA
# 3025   BENIN                  Cabinet de soins Suaaba
# 2987   BENIN   Cabinet de soins infirmiers  la gloire
# 3296   BENIN                Cabinet de soins somperou
#
#                           clean_name_final type_of_facility_visited
# 2996           Cabinet Soins Prive Aafiana         PRIVATE_FACILITY
# 2993  Cabinet Soins La Gloire Ong Entraide         PRIVATE_FACILITY
# 3281                       Cabinet Hoziana         PRIVATE_FACILITY
# 3286                Cabinet Soins Entraide         PRIVATE_FACILITY
# 3295            Cabinet Soins La Tolerance         PRIVATE_FACILITY
# 3268       Cabinet Soins Infirmiers Kokobe   OTHER_NON_ORTHORDOX_HC
# 3301                Cabinet Soins Bekakoua         PRIVATE_FACILITY
# 3025                  Cabinet Soins Suaaba         PRIVATE_FACILITY
# 2987    Cabinet Soins Infirmiers La Gloire         PRIVATE_FACILITY
# 3296                Cabinet Soins Somperou         PRIVATE_FACILITY

# %%
country = btw_100_1k[12]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: EQUATORIAL GUINEA
# Top 10 words:

# %%
country = btw_100_1k[13]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: SOUTH AFRICA
# Top 10 words:
# paediatric 35
# ward 24

# %%
words = ["paediatric", "ward"]

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#           Country                                   Type Abbreviation   count
# 321  South Africa                                 Clinic       CLINIC  3435.0
# 322  South Africa                Community Health Centre          CHC   284.0
# 323  South Africa  Community Health Centre (After hours)         CHCA     9.0
# 324  South Africa         Community Health Centre/Clinic         CHCC     8.0
# 325  South Africa                      District Hospital           DH   254.0
# 326  South Africa                            Health Post           HP    34.0
# 327  South Africa                               Hospital         HOSP     NaN
# 328  South Africa                         Medical Centre           MC     1.0
# 329  South Africa              National Central Hospital          NCH     9.0
# 330  South Africa           Provincial Tertiary Hospital          PTH    17.0
# 331  South Africa                      Regional Hospital           RH    47.0
# 332  South Africa                       Satellite Clinic           SC   205.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#              Country name_of_facility_visited  clean_name_final  \
# 289590  SOUTH AFRICA         Paediatric wards  Paediatric Wards
# 289566  SOUTH AFRICA          Paediatric ward   Paediatric Ward
# 289665  SOUTH AFRICA          Paediatric ward   Paediatric Ward
# 289606  SOUTH AFRICA         Paediatric wards  Paediatric Wards
# 289580  SOUTH AFRICA          Paediatric ward   Paediatric Ward
# 289521  SOUTH AFRICA           Paediatric OPD    Paediatric Opd
# 289189  SOUTH AFRICA         Paediatric ward,   Paediatric Ward
# 289801  SOUTH AFRICA         Paediatric wards  Paediatric Wards
# 289671  SOUTH AFRICA          Paediatric ward   Paediatric Ward
# 289188  SOUTH AFRICA          Paediatric unit   Paediatric Unit
#
#        type_of_facility_visited
# 289590        DISTRICT_HOSPITAL
# 289566        DISTRICT_HOSPITAL
# 289665        DISTRICT_HOSPITAL
# 289606        DISTRICT_HOSPITAL
# 289580        DISTRICT_HOSPITAL
# 289521        DISTRICT_HOSPITAL
# 289189        DISTRICT_HOSPITAL
# 289801           STATE_HOSPITAL
# 289671        DISTRICT_HOSPITAL
# 289188         PRIVATE_HOSPITAL

# %%
country = btw_100_1k[14]
print("Country name:", country)
print("Top 10 words:")
for k,v in islice(freq_dict[country].items(), 10):
    if v>20:
        print(k,v)
# Out:
# Country name: MALAWI
# Top 10 words:
# st 26

# %% [markdown]
# # Between 1k and 10k
#
# Top 20, frequency > 50

# %%
len(btw_1k_10k)
# Out:
# 3

# %%
country = btw_1k_10k[0]
print("Country name:", country)
print("Top 20 words:")
for k,v in islice(freq_dict[country].items(), 20):
    if v>50:
        print(k,v)
# Out:
# Country name: DEMOCRATIC REPUBLIC OF THE CONGO
# Top 20 words:
# saint 106
# la 103
# 2 96
# st 66
# 1 59

# %%
country = btw_1k_10k[1]
print("Country name:", country)
print("Top 20 words:")
for k,v in islice(freq_dict[country].items(), 20):
    if v>50:
        print(k,v)
# Out:
# Country name: CHAD
# Top 20 words:
# urban 328
# 2 93
# nord 75
# est 62
# 1 60

# %%
words = ['urban', 'nord', 'est']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#    Country                   Type Abbreviation   count
# 68    Chad        Centre de Sante           CS     NaN
# 69    Chad          Health Centre           HC  1205.0
# 70    Chad   Hospital de District           HD    70.0
# 71    Chad  Hospital de Nationaux           HN     1.0
# 72    Chad   Hospital de Regional           HR     7.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#       Country name_of_facility_visited clean_name_final  \
# 15162    CHAD          Moussoro urbain   Moussoro Urban
# 24388    CHAD            Bousso Urbain     Bousso Urban
# 23200    CHAD              Mani urbain       Mani Urban
# 15453    CHAD             Dafra urbain      Dafra Urban
# 19488    CHAD         Baktchoro urbain  Baktchoro Urban
# 18747    CHAD           Guereda Urbain    Guereda Urban
# 23912    CHAD            Bousso Urbain     Bousso Urban
# 18146    CHAD          Bongor Urbain 2   Bongor Urban 2
# 18866    CHAD          Moussoro urbain   Moussoro Urban
# 21721    CHAD              Pala-Urbain       Pala Urban
#
#       type_of_facility_visited
# 15162            DISTRICT_HOSP
# 24388            DISTRICT_HOSP
# 23200   OTHER_NON_ORTHORDOX_HC
# 15453   OTHER_NON_ORTHORDOX_HC
# 19488   OTHER_NON_ORTHORDOX_HC
# 18747   OTHER_NON_ORTHORDOX_HC
# 23912            DISTRICT_HOSP
# 18146   OTHER_NON_ORTHORDOX_HC
# 18866            DISTRICT_HOSP
# 21721   OTHER_NON_ORTHORDOX_HC

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#       Country name_of_facility_visited  clean_name_final  \
# 17781    CHAD        Kyabe Urbain Nord  Kyabe Urban Nord
# 21648    CHAD                 ATI Nord          Ati Nord
# 20691    CHAD             AMTIMAN NORD      Amtiman Nord
# 19135    CHAD             AMTIMAN NORD      Amtiman Nord
# 18371    CHAD              Goundi Nord       Goundi Nord
# 22869    CHAD              Diguel Nord       Diguel Nord
# 23555    CHAD              Koumra nord       Koumra Nord
# 24030    CHAD              Diguel Nord       Diguel Nord
# 14880    CHAD                 ATI Nord          Ati Nord
# 15464    CHAD             AMTIMAN NORD      Amtiman Nord
#
#       type_of_facility_visited
# 17781   OTHER_NON_ORTHORDOX_HC
# 21648            DISTRICT_HOSP
# 20691   OTHER_NON_ORTHORDOX_HC
# 19135   OTHER_NON_ORTHORDOX_HC
# 18371              FAITH_BASED
# 22869              FAITH_BASED
# 23555   OTHER_NON_ORTHORDOX_HC
# 24030   OTHER_NON_ORTHORDOX_HC
# 14880            DISTRICT_HOSP
# 15464   OTHER_NON_ORTHORDOX_HC

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[2], case=False))][cols].sample(10)
# Out:
#       Country name_of_facility_visited clean_name_final  \
# 24308    CHAD              Biltine EST      Biltine Est
# 17120    CHAD              Mongo ouest      Mongo Ouest
# 19493    CHAD              Biltine EST      Biltine Est
# 23561    CHAD                  ATI Est          Ati Est
# 15041    CHAD             Bainamar est     Bainamar Est
# 24263    CHAD              Biltine EST      Biltine Est
# 22268    CHAD               Diguel Est       Diguel Est
# 19846    CHAD               Wallia Est       Wallia Est
# 18473    CHAD               Goundi Est       Goundi Est
# 21679    CHAD               Diguel Est       Diguel Est
#
#       type_of_facility_visited
# 24308   OTHER_NON_ORTHORDOX_HC
# 17120   OTHER_NON_ORTHORDOX_HC
# 19493   OTHER_NON_ORTHORDOX_HC
# 23561   OTHER_NON_ORTHORDOX_HC
# 15041            DISTRICT_HOSP
# 24263   OTHER_NON_ORTHORDOX_HC
# 22268              FAITH_BASED
# 19846              FAITH_BASED
# 18473              FAITH_BASED
# 21679   OTHER_NON_ORTHORDOX_HC

# %%
country = btw_1k_10k[2]
print("Country name:", country)
print("Top 20 words:")
for k,v in islice(freq_dict[country].items(), 20):
    if v>50:
        print(k,v)
# Out:
# Country name: MALI
# Top 20 words:
# cabinet 655
# medical 485
# traditherapeute 79
# keneya 58

# %%
words = ['cabinet', 'medical', 'traditherapeute']

# %%
type_dict[type_dict['Country'].str.upper()==country]
# Out:
#     Country                      Type Abbreviation   count
# 209    Mali  Centre de Kinesitherapie           CK     NaN
# 210    Mali           Centre de Sante           CS     NaN
# 211    Mali                    Clinic       CLINIC    94.0
# 212    Mali   Community Health Centre        CSCOM  1294.0
# 213    Mali                  Hospital         HOSP    14.0
# 214    Mali                Polyclinic      PCLINIC    11.0
# 215    Mali    Referral Health Centre        CSREF    61.0
# 216    Mali         Regional Hospital           RH     1.0
# 217    Mali       University Hospital           UH     3.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#       Country                           name_of_facility_visited  \
# 51189    MALI                               Cabinet Médical Nani
# 51529    MALI                        Cabinet de Soins la lumière
# 53953    MALI  Cabinet de consultation et de soin pour sage f...
# 54468    MALI                           Cabinet médical DOUCOURE
# 54681    MALI                             Cabinet de soins Fanto
# 53916    MALI                         Cabinet Médical Dr Diabaté
# 53597    MALI                            Cabinet Keneya Angolême
# 54362    MALI  Cabinet de consultation et de soins pour sage ...
# 55215    MALI                           Cabinet Sage Femme Mande
# 55058    MALI            Cabinet de traditerapeute Keneyabloulon
#
#                                     clean_name_final type_of_facility_visited
# 51189                           Cabinet Medical Nani         PRIVATE_FACILITY
# 51529                       Cabinet Soins La Lumiere         PRIVATE_FACILITY
# 53953   Cabinet Consultation Et Soin Pour Sage Femme         PRIVATE_FACILITY
# 54468                       Cabinet Medical Doucoure         PRIVATE_FACILITY
# 54681                            Cabinet Soins Fanto         PRIVATE_FACILITY
# 53916                     Cabinet Medical Dr Diabate         PRIVATE_FACILITY
# 53597                        Cabinet Keneya Angoleme            TEACHING_HOSP
# 54362  Cabinet Consultation Et Soins Pour Sage Femme         PRIVATE_FACILITY
# 55215                       Cabinet Sage Femme Mande         PRIVATE_FACILITY
# 55058           Cabinet Traditerapeute Keneyabloulon              TRAD_HEALER

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[2], case=False))][cols].sample(10)
# Out:
#       Country                      name_of_facility_visited  \
# 51377    MALI                     Tradithérapeute Nama Sory
# 51349    MALI                          Traditherapeute Jean
# 51093    MALI        Cabinet du tradithérapeute Sado Traoré
# 53087    MALI  Traditherapeute Salifou Doumbia N'Golodougou
# 51493    MALI                     Traditherapeute Abdoulaye
# 51209    MALI                   Tradithérapeute SadioTraoré
# 51403    MALI                         Traditherapeute Cissé
# 53374    MALI                         Traditherapeute Cissé
# 50900    MALI                Traditherapeute niena centrale
# 51001    MALI            Cabinet tradithérapeute le miracle
#
#                                    clean_name_final type_of_facility_visited
# 51377                     Traditherapeute Nama Sory              TRAD_HEALER
# 51349                          Traditherapeute Jean              TRAD_HEALER
# 51093           Cabinet Traditherapeute Sado Traore              TRAD_HEALER
# 53087  Traditherapeute Salifou Doumbia N Golodougou              TRAD_HEALER
# 51493                     Traditherapeute Abdoulaye              TRAD_HEALER
# 51209                   Traditherapeute Sadiotraore              TRAD_HEALER
# 51403                         Traditherapeute Cisse              TRAD_HEALER
# 53374                         Traditherapeute Cisse              TRAD_HEALER
# 50900                Traditherapeute Niena Centrale              TRAD_HEALER
# 51001            Cabinet Traditherapeute Le Miracle              TRAD_HEALER

# %% [markdown]
# # 10k and above
#
# Top 20, frequency > 100

# %%
len(above_10k)
# Out:
# 1

# %%
country = above_10k[0]
print("Country name:", country)
print("Top 20 words:")
for k,v in islice(freq_dict[country].items(), 20):
    if v>100:
        print(k,v)
# Out:
# Country name: NIGERIA
# Top 20 words:
# maternity 1203
# chemist 703
# informant 610
# community 565
# camp 388
# idp 351
# home 338
# mallam 310
# mai 295
# cki 291
# town 278
# setter 265
# bone 251
# nursing 250
# key 246
# wcwc 240
# tba 239
# ibrahim 231
# mal 220
# adamu 217

# %%
words = ['maternity', 'chemist', 'informant', 'community', 'camp', 'idp',
        'home', 'mai', 'cki', 'town', 'setter', 'bone', 'nursing',
        'key', 'wcwc', 'tba', 'mal']

# %%
len(words)
# Out:
# 17

# %%
type_dict[type_dict['Country']=='Nigeria']
# Out:
#      Country                               Type Abbreviation   count
# 254  Nigeria                Basic Health Centre          BHC   568.0
# 255  Nigeria                             Clinic       CLINIC  4354.0
# 256  Nigeria        Comprehensive Health Centre          CHC   434.0
# 257  Nigeria  Comprehensive Primary Health Care         CPHC     NaN
# 258  Nigeria                   Cottage Hospital           CH   149.0
# 259  Nigeria                         Dispensary         DISP  3239.0
# 260  Nigeria                  District Hospital           DH    16.0
# 261  Nigeria             Family Support Program          FSP     NaN
# 262  Nigeria             Federal Medical Centre          FMC    19.0
# 263  Nigeria                   General Hospital           GH   529.0
# 264  Nigeria                      Health Centre           HC  3402.0
# 265  Nigeria                    Health Facility           HF     NaN
# 266  Nigeria                        Health Post           HP  3058.0
# 267  Nigeria                           Hospital         HOSP   148.0
# 268  Nigeria          Maternal and Child Health          MCH     NaN
# 269  Nigeria   Maternal and Child Health Centre         MCHC     NaN
# 270  Nigeria                     Medical Centre           MC    19.0
# 271  Nigeria        Millennium Development Goal          MDG     NaN
# 272  Nigeria                Model Health Centre          MHC   108.0
# 273  Nigeria        Model Primary Health Centre         MPHC    58.0
# 274  Nigeria                  National Hospital           NH     1.0
# 275  Nigeria              Patent Medicine Store          PMS     NaN
# 276  Nigeria             Patent Medicine Vendor          PMV     NaN
# 277  Nigeria                         Polyclinic      PCLINIC    10.0
# 278  Nigeria         Primary Health Care Centre         PHCC     NaN
# 279  Nigeria              Primary Health Centre          PHC  4639.0
# 280  Nigeria                     Rural Hospital           RH    19.0
# 281  Nigeria                     State Hospital           SH    12.0
# 282  Nigeria          Traditional Spirit Healer           TH     NaN
# 283  Nigeria       University Teaching Hospital          UTH    25.0

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)
# Out:
#         Country     name_of_facility_visited             clean_name_final  \
# 109264  NIGERIA               Ngbo Maternity               Ngbo Maternity
# 261782  NIGERIA              Dango maternity              Dango Maternity
# 208249  NIGERIA  Tafawabalewa Town Maternity  Tafawabalewa Town Maternity
# 66993   NIGERIA    Nafisatu mahmud maternity    Nafisatu Mahmud Maternity
# 164828  NIGERIA             kujuru maternity             Kujuru Maternity
# 188978  NIGERIA           Alagarno maternity           Alagarno Maternity
# 191122  NIGERIA          Kafin Iya maternity          Kafin Iya Maternity
# 226380  NIGERIA               Ngbo Maternity               Ngbo Maternity
# 79121   NIGERIA        Urban maternity Azare        Urban Maternity Azare
# 185981  NIGERIA      BALM OF GRACE MATERNITY      Balm Of Grace Maternity
#
#        type_of_facility_visited
# 109264               PHC_CENTER
# 261782               PHC_CENTER
# 208249               PHC_CENTER
# 66993                PHC_CENTER
# 164828               PHC_CENTER
# 188978               PHC_CENTER
# 191122               PHC_CENTER
# 226380               PHC_CENTER
# 79121                PHC_CENTER
# 185981         PRIVATE_FACILITY

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[1], case=False))][cols].sample(10)
# Out:
#         Country               name_of_facility_visited  \
# 193539  NIGERIA                           Habi Chemist
# 112495  NIGERIA                  Alheri Chemist Ingawa
# 186269  NIGERIA  Gabriel Chemist and mobile TBA Kajola
# 262072  NIGERIA                          LADAN CHEMIST
# 196977  NIGERIA                       SULEIMAN CHEMIST
# 194768  NIGERIA                      Babankano Chemist
# 195539  NIGERIA               Danladi  salihu  chemist
# 178553  NIGERIA                           Hudu chemist
# 179150  NIGERIA              Rahamaniya Chemist, Shira
# 194925  NIGERIA                       Dangaske Chemist
#
#                              clean_name_final type_of_facility_visited
# 193539                           Habi Chemist       PATENT_MED_VENDORS
# 112495                  Alheri Chemist Ingawa       PATENT_MED_VENDORS
# 186269  Gabriel Chemist And Mobile Tba Kajola       PATENT_MED_VENDORS
# 262072                          Ladan Chemist       PATENT_MED_VENDORS
# 196977                       Suleiman Chemist       PATENT_MED_VENDORS
# 194768                      Babankano Chemist       PATENT_MED_VENDORS
# 195539                 Danladi Salihu Chemist       PATENT_MED_VENDORS
# 178553                           Hudu Chemist       PATENT_MED_VENDORS
# 179150               Rahamaniya Chemist Shira       PATENT_MED_VENDORS
# 194925                       Dangaske Chemist       PATENT_MED_VENDORS

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[2], case=False))][cols].sample(10)
# Out:
#         Country                  name_of_facility_visited  \
# 190144  NIGERIA               Community informant Mubarak
# 178284  NIGERIA                             Key informant
# 196936  NIGERIA                       Community informant
# 199122  NIGERIA         Jimma Arzika(community Informant)
# 240232  NIGERIA                            INFORMANT  TBA
# 202862  NIGERIA          Community Informant (Baban Yara)
# 181671  NIGERIA                   Community key informant
# 197404  NIGERIA  Community Informant- Gidan Bature Yashim
# 162890  NIGERIA        ChiefJohn Ameh community Informant
# 197501  NIGERIA    COMMUNITY KEY INFORMANT (BABANDI DODO)
#
#                                clean_name_final type_of_facility_visited
# 190144              Community Informant Mubarak       PATENT_MED_VENDORS
# 178284                            Key Informant   OTHER_NON_ORTHORDOX_HC
# 196936                      Community Informant       PATENT_MED_VENDORS
# 199122         Jimma Arzika Community Informant       TRAD_SPIRIT_HEALER
# 240232                            Informant Tba       TRAD_SPIRIT_HEALER
# 202862           Community Informant Baban Yara       TRAD_SPIRIT_HEALER
# 181671                  Community Key Informant       TRAD_SPIRIT_HEALER
# 197404  Community Informant Gidan Bature Yashim       TRAD_SPIRIT_HEALER
# 162890       Chiefjohn Ameh Community Informant   OTHER_NON_ORTHORDOX_HC
# 197501     Community Key Informant Babandi Dodo       TRAD_SPIRIT_HEALER

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[3], case=False))][cols].sample(10)
# Out:
#         Country                   name_of_facility_visited  \
# 199746  NIGERIA                    Community key informant
# 199289  NIGERIA                        Community informant
# 193336  NIGERIA      Kolo aji (Avadar community informant)
# 188206  NIGERIA                    Key community informant
# 198292  NIGERIA         Usman Garba(community informants )
# 188382  NIGERIA         Malam mai jega Community informant
# 184274  NIGERIA          Bone Setter (Community Informant)
# 197571  NIGERIA  COMMUNITY KEY INFORMANT.(SULEIMAN HASHIM)
# 244500  NIGERIA                        Community informant
# 246327  NIGERIA                    Community key informant
#
#                                clean_name_final type_of_facility_visited
# 199746                  Community Key Informant       TRAD_SPIRIT_HEALER
# 199289                      Community Informant            SPIRIT_HEALER
# 193336      Kolo Aji Avadar Community Informant       TRAD_SPIRIT_HEALER
# 188206                  Key Community Informant       TRAD_SPIRIT_HEALER
# 198292         Usman Garba Community Informants       TRAD_SPIRIT_HEALER
# 188382       Malam Mai Jega Community Informant   OTHER_NON_ORTHORDOX_HC
# 184274          Bone Setter Community Informant       TRAD_SPIRIT_HEALER
# 197571  Community Key Informant Suleiman Hashim   OTHER_NON_ORTHORDOX_HC
# 244500                      Community Informant       TRAD_SPIRIT_HEALER
# 246327                  Community Key Informant       PATENT_MED_VENDORS

# %%
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[4], case=False))][cols].sample(10)
# Out:
#         Country   name_of_facility_visited           clean_name_final  \
# 191057  NIGERIA              Kofa IDP Camp              Kofa Idp Camp
# 229340  NIGERIA               NRC IDP Camp               Nrc Idp Camp
# 139155  NIGERIA  Teachers village IDP Camp  Teachers Village Idp Camp
# 166226  NIGERIA           IDP TRANSIT CAMP           Idp Transit Camp
# 211173  NIGERIA             IDP CAMP KWALE             Idp Camp Kwale
# 155695  NIGERIA           IDP camp Malkohi           Idp Camp Malkohi
# 144381  NIGERIA        Ngala ISS IDPS camp        Ngala Iss Idps Camp
# 208777  NIGERIA    TSANGAYA IDP CAMP CLINI    Tsangaya Idp Camp Clini
# 155834  NIGERIA   20 HOUSES IDP CAMP CLINC   20 Houses Idp Camp Clinc
# 270145  NIGERIA                   IDP Camp                   Idp Camp
#
#        type_of_facility_visited
# 191057               PHC_CENTER
# 229340               PHC_CENTER
# 139155               PHC_CENTER
# 166226               PHC_CENTER
# 211173               PHC_CENTER
# 155695               PHC_CENTER
# 144381               PHC_CENTER
# 208777               PHC_CENTER
# 155834               PHC_CENTER
# 270145               PHC_CENTER

# %%
print("word:", words[6])
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[6], case=False))][cols].sample(10)
# Out:
# word: home
#         Country               name_of_facility_visited  \
# 195247  NIGERIA  Dadin Kowa Nursing and Meternity Home
# 203333  NIGERIA                  OPEOLU MATERNITY HOME
# 267403  NIGERIA             ALHERI NURSING HOME BOKKOS
# 202314  NIGERIA                               TBA HOME
# 158580  NIGERIA  MWAM Nursing and Maternity Home Mirke
# 258873  NIGERIA                 HAMDALA MATERNITY HOME
# 108071  NIGERIA               SHOLLYLAD MATERNITY HOME
# 116871  NIGERIA    Al Hilal Nursing home and maternity
# 196888  NIGERIA                   Kainuwa Nursing Home
# 90754   NIGERIA             ALHERI NURSING HOME BOKKOS
#
#                              clean_name_final type_of_facility_visited
# 195247  Dadin Kowa Nursing And Meternity Home         PRIVATE_FACILITY
# 203333                  Opeolu Maternity Home         PRIVATE_FACILITY
# 267403             Alheri Nursing Home Bokkos         PRIVATE_FACILITY
# 202314                               Tba Home       TRAD_SPIRIT_HEALER
# 158580  Mwam Nursing And Maternity Home Mirke         PRIVATE_FACILITY
# 258873                 Hamdala Maternity Home         PRIVATE_FACILITY
# 108071               Shollylad Maternity Home               PHC_CENTER
# 116871    Al Hilal Nursing Home And Maternity   OTHER_NON_ORTHORDOX_HC
# 196888                   Kainuwa Nursing Home         PRIVATE_FACILITY
# 90754              Alheri Nursing Home Bokkos         PRIVATE_FACILITY

# %%
word = words[7]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: mai
#         Country                         name_of_facility_visited  \
# 196209  NIGERIA                 Chindo Maimaganin Gargajiya Gori
# 187348  NIGERIA  Mal. Baba Ibrahim mai maganin gargajiya Bambam.
# 189635  NIGERIA                                    Kafin maigari
# 237785  NIGERIA                                Mal Abdu Mai Yaji
# 235650  NIGERIA                                London Mai Dorowa
# 202949  NIGERIA                                 Abbas Mai Magani
# 178923  NIGERIA                      Adamuje Mai Magani Yeskawal
# 239976  NIGERIA                                 Kachalla Ali Mai
# 195581  NIGERIA                            Abdullahi  mai magani
# 197794  NIGERIA                       Abdullahi Garba Mai Magani
#
#                                      clean_name_final type_of_facility_visited
# 196209               Chindo Maimaganin Gargajiya Gori       TRAD_SPIRIT_HEALER
# 187348  Mal Baba Ibrahim Mai Maganin Gargajiya Bambam               PHC_CENTER
# 189635                                  Kafin Maigari               PHC_CENTER
# 237785                              Mal Abdu Mai Yaji       TRAD_SPIRIT_HEALER
# 235650                              London Mai Dorowa               PHC_CENTER
# 202949                               Abbas Mai Magani       TRAD_SPIRIT_HEALER
# 178923                    Adamuje Mai Magani Yeskawal       TRAD_SPIRIT_HEALER
# 239976                               Kachalla Ali Mai       PATENT_MED_VENDORS
# 195581                           Abdullahi Mai Magani       TRAD_SPIRIT_HEALER
# 197794                     Abdullahi Garba Mai Magani       TRAD_SPIRIT_HEALER

# %%
word = words[8]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: cki
#         Country   name_of_facility_visited         clean_name_final  \
# 201600  NIGERIA       CKI Doko Bayan Tasha     Cki Doko Bayan Tasha
# 201894  NIGERIA         CKI Gagarawa Tasha       Cki Gagarawa Tasha
# 193136  NIGERIA  CKI Mal. Ali Sarkin  Aska  Cki Mal Ali Sarkin Aska
# 182126  NIGERIA     Galadiman wanzamai CKI   Galadiman Wanzamai Cki
# 203854  NIGERIA        CKI (TBA) Rabi Musa        Cki Tba Rabi Musa
# 198282  NIGERIA           CKI Galadi Yamma         Cki Galadi Yamma
# 200739  NIGERIA         CKI(Sarkin Magani)        Cki Sarkin Magani
# 197639  NIGERIA        SULEIMAN HABU (CKI)        Suleiman Habu Cki
# 202156  NIGERIA       CKI  Amadu Dan Burin      Cki Amadu Dan Burin
# 201295  NIGERIA                   Muku CKI                 Muku Cki
#
#        type_of_facility_visited
# 201600       PATENT_MED_VENDORS
# 201894            SPIRIT_HEALER
# 193136       TRAD_SPIRIT_HEALER
# 182126   OTHER_NON_ORTHORDOX_HC
# 203854   OTHER_NON_ORTHORDOX_HC
# 198282   OTHER_NON_ORTHORDOX_HC
# 200739   OTHER_NON_ORTHORDOX_HC
# 197639       TRAD_SPIRIT_HEALER
# 202156       TRAD_SPIRIT_HEALER
# 201295       TRAD_SPIRIT_HEALER

# %%
word = words[9]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: town
#         Country  name_of_facility_visited         clean_name_final  \
# 204099  NIGERIA            Town Maternity           Town Maternity
# 181861  NIGERIA  Town Maternity, Alkakeri  Town Maternity Alkakeri
# 209346  NIGERIA     Dambam Town Maternity    Dambam Town Maternity
# 213727  NIGERIA            Town Maternity           Town Maternity
# 142154  NIGERIA   Town Maternity Alkaleri  Town Maternity Alkaleri
# 234409  NIGERIA      Ningi town maternity     Ningi Town Maternity
# 211639  NIGERIA   Jama'are Town maternity  Jama Are Town Maternity
# 147086  NIGERIA     Gamawa Town Maternity    Gamawa Town Maternity
# 234556  NIGERIA    Town Maternity, Bununu    Town Maternity Bununu
# 124853  NIGERIA       Itas Town Maternity      Itas Town Maternity
#
#        type_of_facility_visited
# 204099               PHC_CENTER
# 181861               PHC_CENTER
# 209346               PHC_CENTER
# 213727               PHC_CENTER
# 142154               PHC_CENTER
# 234409               PHC_CENTER
# 211639               PHC_CENTER
# 147086               PHC_CENTER
# 234556               PHC_CENTER
# 124853               PHC_CENTER

# %%
word = words[10]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: setter
#         Country          name_of_facility_visited  \
# 241122  NIGERIA              Walawala bone setter
# 202398  NIGERIA    MUHAMMADU DANLAMSO Bone Setter
# 194004  NIGERIA             ALH. Isah Bone setter
# 197430  NIGERIA        Jibrin Adamu (Bone Setter)
# 203559  NIGERIA      Mohammed Ibrahim Bone Setter
# 201764  NIGERIA                       Bone Setter
# 187225  NIGERIA  Alh Ebantu Tradition bone setter
# 185113  NIGERIA           KPOYE INKIA BONE SETTER
# 195248  NIGERIA              ABU NEPA BONE SETTER
# 197483  NIGERIA        Na'abu Adamu (Bone setter)
#
#                         clean_name_final type_of_facility_visited
# 241122              Walawala Bone Setter       TRAD_SPIRIT_HEALER
# 202398    Muhammadu Danlamso Bone Setter   OTHER_NON_ORTHORDOX_HC
# 194004              Alh Isah Bone Setter   OTHER_NON_ORTHORDOX_HC
# 197430          Jibrin Adamu Bone Setter       TRAD_SPIRIT_HEALER
# 203559      Mohammed Ibrahim Bone Setter       TRAD_SPIRIT_HEALER
# 201764                       Bone Setter   OTHER_NON_ORTHORDOX_HC
# 187225  Alh Ebantu Tradition Bone Setter       TRAD_SPIRIT_HEALER
# 185113           Kpoye Inkia Bone Setter       TRAD_SPIRIT_HEALER
# 195248              Abu Nepa Bone Setter       TRAD_SPIRIT_HEALER
# 197483          Na Abu Adamu Bone Setter       TRAD_SPIRIT_HEALER

# %%
word = words[12]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: nursing
#         Country               name_of_facility_visited  \
# 195700  NIGERIA                   Kainuwa Nursing Home
# 164451  NIGERIA                    Nakowa Nursing Home
# 108581  NIGERIA  Dadin Kowa Nursing and Maternity Home
# 165249  NIGERIA           Haske Weta Nursing Home Song
# 157267  NIGERIA         St Francis Nursing Home Bazza.
# 244159  NIGERIA             SHALOM NURSING HOME ASHAKA
# 199359  NIGERIA      Ayeboi Nursing and Maternity Home
# 94083   NIGERIA      Nasara Nursing and Maternity Home
# 257109  NIGERIA                     Dange Nursing home
# 193323  NIGERIA         Victoria Memorial Nursing Home
#
#                              clean_name_final type_of_facility_visited
# 195700                   Kainuwa Nursing Home         PRIVATE_FACILITY
# 164451                    Nakowa Nursing Home         PRIVATE_FACILITY
# 108581  Dadin Kowa Nursing And Maternity Home         PRIVATE_FACILITY
# 165249           Haske Weta Nursing Home Song         PRIVATE_FACILITY
# 157267          St Francis Nursing Home Bazza         PRIVATE_FACILITY
# 244159             Shalom Nursing Home Ashaka         PRIVATE_FACILITY
# 199359      Ayeboi Nursing And Maternity Home         PRIVATE_FACILITY
# 94083       Nasara Nursing And Maternity Home         PRIVATE_FACILITY
# 257109                     Dange Nursing Home         PRIVATE_FACILITY
# 193323         Victoria Memorial Nursing Home               PHC_CENTER

# %%
word = words[13]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: key
#         Country                           name_of_facility_visited  \
# 110841  NIGERIA                     Christiana Ogaba Key Informant
# 245433  NIGERIA                            Community key informant
# 188496  NIGERIA                         KASUWAR KOFA KEY INFORMANT
# 185327  NIGERIA                            Community key informant
# 194546  NIGERIA                       Key Informants Site (Shabbo)
# 165887  NIGERIA                    Fatima Hassan IDP Key Informant
# 202092  NIGERIA  Bakangizo Pharmacy (Pharm. Fortune Onwumelu) -...
# 200166  NIGERIA                   Key Informant - Mallam Umar Sule
# 203280  NIGERIA                     Karen Pharmacy (Key informant)
# 245209  NIGERIA                            Community key informant
#
#                                          clean_name_final  \
# 110841                     Christiana Ogaba Key Informant
# 245433                            Community Key Informant
# 188496                         Kasuwar Kofa Key Informant
# 185327                            Community Key Informant
# 194546                         Key Informants Site Shabbo
# 165887                    Fatima Hassan Idp Key Informant
# 202092  Bakangizo Pharmacy Pharm Fortune Onwumelu Key ...
# 200166                     Key Informant Mallam Umar Sule
# 203280                       Karen Pharmacy Key Informant
# 245209                            Community Key Informant
#
#        type_of_facility_visited
# 110841   OTHER_NON_ORTHORDOX_HC
# 245433   OTHER_NON_ORTHORDOX_HC
# 188496       PATENT_MED_VENDORS
# 185327   OTHER_NON_ORTHORDOX_HC
# 194546       TRAD_SPIRIT_HEALER
# 165887       TRAD_SPIRIT_HEALER
# 202092       PATENT_MED_VENDORS
# 200166       TRAD_SPIRIT_HEALER
# 203280       PATENT_MED_VENDORS
# 245209   OTHER_NON_ORTHORDOX_HC

# %%
word = words[14]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: wcwc
#         Country name_of_facility_visited    clean_name_final  \
# 169272  NIGERIA                 WCWC ANK            Wcwc Ank
# 104500  NIGERIA       WCWC Birnin magaji  Wcwc Birnin Magaji
# 162841  NIGERIA                WCWC Anka           Wcwc Anka
# 209309  NIGERIA             WCWC BUNGUDU        Wcwc Bungudu
# 174336  NIGERIA         WCWC Sabin Birni    Wcwc Sabin Birni
# 223883  NIGERIA             WCWC Maradun        Wcwc Maradun
# 175057  NIGERIA             WCWC BUNGUDU        Wcwc Bungudu
# 84803   NIGERIA            WCWC BUKKUYUM       Wcwc Bukkuyum
# 146987  NIGERIA           Dr karima wcwc      Dr Karima Wcwc
# 173325  NIGERIA                WCWC Anka           Wcwc Anka
#
#        type_of_facility_visited
# 169272               PHC_CENTER
# 104500               PHC_CENTER
# 162841               PHC_CENTER
# 209309               PHC_CENTER
# 174336               PHC_CENTER
# 223883               PHC_CENTER
# 175057               PHC_CENTER
# 84803                PHC_CENTER
# 146987               PHC_CENTER
# 173325               PHC_CENTER

# %%
word = words[15]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: tba
#         Country name_of_facility_visited       clean_name_final  \
# 191623  NIGERIA              Aishetu TBA            Aishetu Tba
# 197965  NIGERIA                Saude TBA              Saude Tba
# 242869  NIGERIA    Koji Zhira Tukuli TBA  Koji Zhira Tukuli Tba
# 244789  NIGERIA                EDWIN TBA              Edwin Tba
# 192444  NIGERIA             TBA Ekeremor           Tba Ekeremor
# 201579  NIGERIA         Paulina Obed TBA       Paulina Obed Tba
# 192099  NIGERIA              Ede TBA Odi            Ede Tba Odi
# 192813  NIGERIA             TBA Aleibiri           Tba Aleibiri
# 247351  NIGERIA               HAJARA TBA             Hajara Tba
# 202559  NIGERIA               Halima TBA             Halima Tba
#
#        type_of_facility_visited
# 191623       TRAD_SPIRIT_HEALER
# 197965   OTHER_NON_ORTHORDOX_HC
# 242869   OTHER_NON_ORTHORDOX_HC
# 244789   OTHER_NON_ORTHORDOX_HC
# 192444       TRAD_SPIRIT_HEALER
# 201579   OTHER_NON_ORTHORDOX_HC
# 192099       TRAD_SPIRIT_HEALER
# 192813   OTHER_NON_ORTHORDOX_HC
# 247351   OTHER_NON_ORTHORDOX_HC
# 202559       TRAD_SPIRIT_HEALER

# %%
word = words[16]
print("word:", word)
sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(word+' | '+word, case=False))][cols].sample(10)
# Out:
# word: mal
#         Country name_of_facility_visited      clean_name_final  \
# 243470  NIGERIA             FANNA MALLUM          Fanna Mallum
# 244784  NIGERIA              NPHC malisa           Nphc Malisa
# 202105  NIGERIA          Mal.jamilu musa       Mal Jamilu Musa
# 155519  NIGERIA            PHONE Malaete         Phone Malaete
# 198503  NIGERIA     Albert B Mali Chimbi  Albert B Mali Chimbi
# 196459  NIGERIA   Mal. Inusa madugu(CKI)  Mal Inusa Madugu Cki
# 215988  NIGERIA           Mono Malam isa        Mono Malam Isa
# 175861  NIGERIA                Mal Muazu             Mal Muazu
# 190683  NIGERIA        SUNNA ANIMAL DRUG     Sunna Animal Drug
# 197435  NIGERIA      Furera mal. Muktari    Furera Mal Muktari
#
#        type_of_facility_visited
# 243470   OTHER_NON_ORTHORDOX_HC
# 244784               PHC_CENTER
# 202105   OTHER_NON_ORTHORDOX_HC
# 155519               PHC_CENTER
# 198503       TRAD_SPIRIT_HEALER
# 196459       TRAD_SPIRIT_HEALER
# 215988               PHC_CENTER
# 175861   OTHER_NON_ORTHORDOX_HC
# 190683       PATENT_MED_VENDORS
# 197435            SPIRIT_HEALER

# %%
country = above_10k[0]
print("Country name:", country)
print("Top 20 words:")
for k,v in islice(freq_dict[country].items(), 20):
    if v>50:
        print(k,v)
        
type_dict[type_dict['Country'].str.upper()==country]

sample[(sample['Country']==country) & 
       (sample['clean_name_final'].str.contains(words[0], case=False))][cols].sample(10)

# %% [markdown]
# # New Additions

# %%
# New rows to be added
additions = [["South Sudan", "Clinic", "CLINIC", np.nan],
             ["Cameroon", "Cabinet de Soins", "CABINET SOINS", np.nan],
             ["Gabon", "Infirmerie", "INFIRMERIE", np.nan],
             ["Gabon", "Cabinet de Soins", "CABINET SOINS", np.nan],
             ["Niger", "Case de Sante", "CASE SANTE", np.nan],
             ["Congo", "Cabinet de Soins", "CABINET SOINS", np.nan],
             ["Congo", "Clinic", "CLINIC", np.nan],
             ["Benin", "Cabinet de Soins", "CABINET SOINS", np.nan],
             ["Mali", "Cabinet Medical", "CABINET MEDICAL", np.nan],
             ["Mali", "Traditherapeute", 'TRADITHERAPEUTE', np.nan],
             ['Nigeria', 'Maternity', 'MATERNITY', np.nan],
             ['Nigeria', 'Town Maternity', 'TOWN MATERNITY', np.nan],
             ['Nigeria', 'Nursing and Maternity Home', 'Nursing and Maternity Home', np.nan],
             ['Nigeria', 'Nursing Home', 'Nursing Home', np.nan],
             ['Nigeria', 'Chemist', 'Chemist', np.nan]]

# %%
type_dict_additions = pd.DataFrame(additions, columns = ['Country', 'Type', 'Abbreviation', 'count'])
type_dict_additions.head()
# Out:
#        Country              Type   Abbreviation  count
# 0  South Sudan            Clinic         CLINIC    NaN
# 1     Cameroon  Cabinet de Soins  CABINET SOINS    NaN
# 2        Gabon        Infirmerie     INFIRMERIE    NaN
# 3        Gabon  Cabinet de Soins  CABINET SOINS    NaN
# 4        Niger     Case de Sante     CASE SANTE    NaN

# %%
type_dict.shape
# Out:
# (401, 4)

# %%
# Add new rows to type dictionary
type_dict = pd.concat([type_dict, type_dict_additions])

# %% [markdown]
# # Spelling Check

# %%
# hospital
saveDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\spelling check"
filename = "hospital.txt"
file1 = open(os.path.join(saveDir, filename),"w")
# obtain a list of words that appear in clean_name_final
clean_names = ' '.join(list(sample['clean_name_final'].str.lower())).split()
# keep just words that start with h and have length greater than 4
names_h = [name for name in clean_names if name.startswith('h') and len(name)>4]
file1.write(' '.join(names_h))
file1.close() 

# generate word frequency dictionary
sym_spell = SymSpell()
saveDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\spelling check"
filename = "hospital.txt"
corpus_path = os.path.join(saveDir, filename)
sym_spell.create_dictionary(corpus_path)
d = sym_spell.words

# compute similarity score with respect to the original word
hospital_spellings = []
for word in d.keys():
    if fuzz.ratio(word, 'hospital')>80:
        hospital_spellings.append(word)
        print(word)
# Out:
# hospial
# hosipital
# haspital
# hpspital
# hosital
# hodpital
# hopistal
# hospita
# hispital
# hosfital
# hosputal
# hospitl
# hoslital
# hospitak
# hospitsl
# hospitaal
# hospital

# %%
# clinic
saveDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\spelling check"
filename = "clinic.txt"
file1 = open(os.path.join(saveDir, filename),"w")
clean_names = ' '.join(list(sample['clean_name_final'].str.lower())).split()
names_c = [name for name in clean_names if name.startswith('c') and len(name)>=4]
file1.write(' '.join(names_c))
file1.close() 

sym_spell = SymSpell()
saveDir = r"C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\Africa\spelling check"
filename = "clinic.txt"
corpus_path = os.path.join(saveDir, filename)
sym_spell.create_dictionary(corpus_path)
d = sym_spell.words

clinic_spellings = []
for word in d.keys():
    if fuzz.ratio(word, 'clinic')>80:
        clinic_spellings.append(word)
        print(word)
# Out:
# clinica
# clinical
# clinic
# cilinic
# clini
# clinc
# clnic
# chinic
# clunic
# clanic
# cinic
# clinit
# clinlc
# clinin
# chlinic
# clinix

# %%
# correct misspellings 
sample['clean_name_final'] = sample['clean_name_final'].str.replace('|'.join(hospital_spellings),'hospital',
                                                                            case=False)\
.str.replace('|'.join(clinic_spellings),'clinic',case=False)

# %%
def remove_type_info(df, type_dict, clean_name, clean_name_final, country):
    # remove whitespace between abbreviations of length 2 or 3
    # e.g. change C S to CS
    
    # obtain abbreviations of length 2 or 3
    tmp = type_dict[type_dict['Abbreviation'].str.len()<=3]['Abbreviation'].unique()
    # sort by decreasing length
    tmp = sorted(tmp, key=len, reverse=True)
    # change it to the pattern '^c s ' or ' c s$'
    tmp_dict = {}
    for t in tmp:
        tmp_dict[t] = ['^'+' '.join(list(t))+' ', ' '+' '.join(list(t))+'$']
    # replace the pattern with 'cs'
    for t in tmp:
        pats = tmp_dict[t]
        df[clean_name] = df[clean_name].str.replace(pats[0], t+' ',case=False)\
        .str.replace(pats[1], ' '+t, case=False)
        
    # remove type information
    df_grouped = df.groupby(country)
    res = pd.DataFrame()

    for group_name, df_group in df_grouped:
        # obtain the type dictionary for that country
        tmp = type_dict[type_dict['Country'].str.upper()==group_name.upper()]

        # facility types for that country
        types = list(tmp['Type'])
        type_keywords = set()
        for t in types:
            # add the full facility type 
            t = t.title()
            type_keywords.add(t)                 

            # add individual words as well
            t = t.replace('/', ' ')
            words = t.split(' ')
            # skip words that have punctuation / numbers and have length <= 3 (e.g. de, (major))
            words = [w for w in words if w.isalpha() and len(w)>3]
            for w in words:
                type_keywords.add(w)

        # obtain the list of type keywords and sort in descending length
        type_keywords = list(type_keywords)
        type_keywords = sorted(type_keywords, key=lambda s: -len(s))

        # abbreviations for that country
        abbrevs = set(tmp['Abbreviation'])

        abb_keywords = []
        for abbrev in abbrevs:
            # e.g. for CS, 4 patterns are considered: '^CS ', ' CS ', ' CS$', '^CS$'
            abbrev = abbrev.title()
            abb_keywords.extend(['^'+abbrev+'\s', '\s'+abbrev+'\s', '\s'+abbrev+'$',
                                '^'+abbrev+'$'])

        # obtain the list of abbreviation keywords and sort in descending length
        abb_keywords = sorted(abb_keywords, key=lambda s: -len(s))  

        # some country-specific adjustments
        if group_name == 'UGANDA':
            df_group['clean_name'] = df_group['clean_name'].str.replace("HC II$", "HCII", case=False)\
            .str.replace("HC III$", "HCIII", case=False)\
            .str.replace("HC IV$", "HCIV", case=False)

        if group_name == 'MALAWI':
            df_group['clean_name'] = df_group['clean_name'].str.replace(" DHO$", " DH", case=False)

        if group_name == "ERITREA":
            df_group['clean_name'] = df_group['clean_name'].str.replace(" HO$", " HOSP", case=False)

        if group_name == 'MADAGASCAR':
            df_group['clean_name'] = df_group['clean_name'].str.replace("csb 1", " csb1", case=False)
            df_group['clean_name'] = df_group['clean_name'].str.replace("csb 2", " csb2", case=False)

        # handle situations when type is 'Hospital District' in the type dictionary 
        # but name column has 'District Hospital' in ISS data
        type_len_2 = [t for t in type_keywords if len(t.split())==2]
        for t in type_len_2:
            df_group[clean_name] = df_group[clean_name].str.title()\
            .str.replace(' '.join(t.split()[::-1]), t, case=False)

        # remove type information using keywords generated above
        # remove meaningless connecting words like de, do, da, du
        df_group[clean_name_final] = df_group[clean_name].str.title()\
            .str.replace('|'.join(type_keywords), '')\
            .str.replace('|'.join(abb_keywords), ' ')\
            .str.strip()\
            .str.replace('^de | de | de$|^de$|^do | do | do$|^do$|^da | da | da$|^da$|^du | du | du$|^du$', 
                         ' ', case=False)\
            .str.replace("  ", " ")\
            .str.strip()\
            .str.title()
        res = pd.concat([res, df_group])
    return res

# %%
def extract_type(df, clean_name, clean_name_final, extract_type):
    extract_types = []

    for idx, row in df.iterrows():
        name = row[clean_name].upper()
        name_final = row[clean_name_final].upper()

        # if clean_name_final is exactly the same as clean_name,
        # this indicates no type information can be extracted, thus append NA
        if name.upper() == name_final.upper():
            extract_types.append(np.nan)

        else:
            name = OrderedSet(name.split())
            name_final = OrderedSet(name_final.split())
            # find the difference between two names
            diff = ' '.join(list(name.difference(name_final)))
            extract_types.append(diff.strip())

    # remove de, do, da, du at start or end of extract_type
    # replace empty string with NA
    df[extract_type] = extract_types
    df[extract_type] = df[extract_type].str.strip()\
        .str.replace("  ", " ")\
        .str.replace('^de |^do |^da |^du | du$| de$| do$| da$|^de$|^do$|^da$|^du$', '', case=False)\
        .str.replace('^de |^do |^da |^du | du$| de$| do$| da$|^de$|^do$|^da$|^du$', '', case=False)\
        .str.strip()\
        .str.title()\
        .replace('',np.nan)
    # replace empty string with NA
    df['clean_name_final'].replace('', np.nan, inplace=True)

# %%
def map_type(df, country, extract_type, sub_type, score, type_dict):
    df_grouped = df.groupby(country)
    res = pd.DataFrame()
    for country_name in df[country].unique():
        df_group = df[df[country]==country_name]
        # obtain facility types and abbreviations for that country
        tmp = type_dict[type_dict['Country'].str.upper()==country_name.upper()]
        types, abbrevs = tmp['Type'], tmp['Abbreviation']
        sub_types = []
        scores = []

        for idx, row in df_group.iterrows():
            # if extract_type is NA, just append NA
            if not isinstance(row[extract_type],str):
                sub_types.append(np.nan)
                scores.append(np.nan)

            # find best match
            else:
                match, match_score = process.extractOne(row[extract_type], list(types)+list(abbrevs), 
                                               scorer = fuzz.ratio)
                scores.append(match_score)
                # if best match is abbreviation, map it to the corresponding type
                if match in list(abbrevs):
                    match_type = tmp[tmp['Abbreviation']==match]['Type'].iloc[0]
                    sub_types.append(match_type)
                else:
                    sub_types.append(match) 
        df_group[sub_type] = sub_types
        df_group[score] = scores
        res = pd.concat([res, df_group])
    return res

# %%
# remove type information
res = remove_type_info(sample, type_dict=type_dict, clean_name='clean_name_final', 
                       clean_name_final='clean_name_final', country='Country')

# %%
# obtain facility type extracted
extract_type(df=res, clean_name='clean_name', 
             clean_name_final='clean_name_final', extract_type='extract_type')

# %%
print("Percentage of NA in extract type column:",
     round(res['extract_type'].isna().sum()/res.shape[0]*100,1))
print("Number of NA values in extract type column:", res[pd.isna(res['extract_type'])].shape[0])
# Out:
# Percentage of NA in extract type column: 85.1
# Number of NA values in extract type column: 21036

# %%
# map facility type extracted to type in type dictionary
res = map_type(df=res, country = 'Country', extract_type='extract_type', 
               sub_type='sub_type', score='score', type_dict=type_dict)

# %%
print("Summary statistics of match score:")
res['score'].describe()
# Out:
# Summary statistics of match score:
# count    3672.000000
# mean       94.676198
# std        13.305599
# min        40.000000
# 25%       100.000000
# 50%       100.000000
# 75%       100.000000
# max       100.000000
# Name: score, dtype: float64

# %%
# randomly sample rows to examine results
cols = ['Country', 'name_of_facility_visited', 'clean_name', 'clean_name_final', 'extract_type',
       'sub_type', 'score']
res[~pd.isna(res['extract_type'])][cols].sample(5)
# Out:
#         Country    name_of_facility_visited                  clean_name  \
# 54351      MALI  Cabinet médical fraternité  Cabinet Medical Fraternite
# 180954  NIGERIA           Shakatafi chemist           Shakatafi Chemist
# 32982     GABON        Infirmerie de la CEB        Infirmerie De La Ceb
# 194308  NIGERIA       Alheri Chemist Ingawa       Alheri Chemist Ingawa
# 201542  NIGERIA                    TBA HOME                    Tba Home
#
#        clean_name_final     extract_type         sub_type  score
# 54351        Fraternite  Cabinet Medical  Cabinet Medical  100.0
# 180954        Shakatafi          Chemist          Chemist  100.0
# 32982            La Ceb       Infirmerie       Infirmerie  100.0
# 194308    Alheri Ingawa          Chemist          Chemist  100.0
# 201542              Tba             Home     Nursing Home   50.0

# %%
# Add new results back to the whole dataset
res = pd.concat([res, df_iss[~((pd.isna(df_iss['extract_type']))&(df_iss['clean_name_final'].str.count(' ')>0))]])

# %%
res.shape
# Out:
# (305182, 51)

# %%
# Export results
cols= ['index', 'Country', 'clean_name', 'clean_name_final',
       'extract_type', 'sub_type', 'score']
saveDir = r'C:\\Users\\DUANYUEYUN\\Documents\\GRID3\\Health facilities\\Data\\Africa'
res[cols].to_csv(saveDir+"\\clean_names_types_1130.csv", index=False)

# %%
# Export results
type_dict.to_csv(saveDir+'\\type_dict_augmented_1130.csv', index=False)
