# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fiona
import geopandas as gpd
import folium
import os
from folium.plugins import MarkerCluster
from math import radians, sin, cos, acos

# %%
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', None)

# %%
# data import
dataDir = r'C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\SLE\Cleaned Data\Overall'

filename = 'UNICEF DPPI 2016_cleaned_0814.csv'
unicef = pd.read_csv(dataDir+'\\'+filename)

filename = 'sara_cleaned_0814.csv'
sara = pd.read_csv(dataDir+'\\'+filename)

filename = 'ISS_cleaned_0814.csv'
iss = pd.read_csv(dataDir+'\\'+filename)

# %%
# find the union of columns in each dataset
cols = set(unicef.columns).union(set(sara.columns))
cols = cols.union(set(iss.columns))

# %%
# if a column doesn't exist, create that column with all values being NA
for column in cols:
    if column not in unicef.columns:
        unicef[column] = np.nan

# %%
# if a column doesn't exist, create that column with all values being NA
for column in cols:
    if column not in sara.columns:
        sara[column] = np.nan

# %%
# if a column doesn't exist, create that column with all values being NA
for column in cols:
    if column not in iss.columns:
        iss[column] = np.nan

# %%
# combine datasets
combined = pd.concat([unicef, sara, iss])

# %%
# write csv file
dataDir = r'C:\Users\DUANYUEYUN\Documents\GRID3\Health facilities\Data\SLE\Cleaned Data'
combined.to_csv(dataDir + '\\combined_list_full_0814.csv',
               index=False)

# %%
# drop points with no coordinates
combined_dropped = combined.dropna(subset=["Longitude", 'Latitude'])
combined_dropped.to_csv(dataDir + '\\combined_list_geo_0814.csv',
               index=False)

# %%
print("Number of points in combined list:", combined.shape[0])
# Out:
# Number of points in combined list: 4097

# %%
print("Number of points in combined list with no missing coordinates:", combined_dropped.shape[0])
# Out:
# Number of points in combined list with no missing coordinates: 3943

# %%
# add feature sequence
seq = gpd.read_file(r'C:\Users\DUANYUEYUN\Documents\ArcGIS\Projects\SLE\SLE.gdb', 
                     driver='FileGDB', layer= 'combined_FindIdentical')
combined = gpd.read_file(r'C:\Users\DUANYUEYUN\Documents\ArcGIS\Projects\SLE\SLE.gdb', 
                     driver='FileGDB', layer= 'combined')

# %%
combined.reset_index(inplace=True)

combined['index'] = combined['index']+1

combined.rename(columns={'index':'IN_FID'}, inplace=True)

df = combined.merge(seq.drop(columns=['geometry']), on = 'IN_FID')
df.drop(columns=['IN_FID'], inplace=True)

# %%
# sort the dataframe
df.sort_values(by=['FEAT_SEQ', 'District', 'Chiefdom', 'Facility_Name',
                   'Facility_Type', 'Source'], inplace=True)

# %%
df.to_csv(dataDir + '\\combined_list_0814.csv',
          index=False)

# %%
df[df['FEAT_SEQ']==501].head(3)
# Out:
#         Region   District          Chiefdom                 Facility_Name  \
# 3089  Northern  Koinadugu  Wara Wara Yagala    KABALA GOVERNMENT HOSPITAL
# 3090  Northern  Koinadugu  Wara Wara Yagala   KABALA GOVERNMENTS HOSPITAL
# 3091  Northern  Koinadugu  Wara Wara Yagala  KABALA GOVT. HOSP MCH STATIC
#
#          ID Facility_Type  Latitude  Longitude  Altitude  GPS_accuracy  \
# 3089  478.0  GENERAL_HOSP  9.586599 -11.548426       NaN           NaN
# 3090  473.0  GENERAL_HOSP  9.586608 -11.548380       NaN           NaN
# 3091   57.0  GENERAL_HOSP  9.586994 -11.547792       NaN           NaN
#
#      Functional_Status  Catchment_population  \
# 3089              None                   NaN
# 3090              None                   NaN
# 3091              None                   NaN
#
#       Number_of_villages_within_the_catchment_area Mobile_Network_coverage  \
# 3089                                           NaN                    None
# 3090                                           NaN                    None
# 3091                                           NaN                    None
#
#               Short_Name Source Location_of_facility facility_fp_acs_copy  \
# 3089              Kabala    ISS                 None                    N
# 3090            Kabala s    ISS                 None                    N
# 3091  Kabala  Mch Static    ISS                 None                 None
#
#      cross_referenced      supervised_by_dsno Accomodation_Provided  \
# 3089             None                 1_MONTH                  None
# 3090             None  NOT_IN_THE_PAST_1_YEAR                  None
# 3091             None      MORE_THAN_6_MONTHS                  None
#
#      Urban_rural Capacity_of_accommodation        Date Waypoint_name  \
# 3089        None                      None  2020-01-28          None
# 3090        None                      None  2019-10-11          None
# 3091        None                      None  2018-11-17          None
#
#      surveillance_fp_training BeMOC_ priority_level physiotherapy_unit  \
# 3089                  1_2_YRS   None              H                  N
# 3090          MORE_THAN_2_YRS   None              H                  N
# 3091                  1_2_YRS   None              H                  N
#
#      Number_of_housing_units  \
# 3089                    None
# 3090                    None
# 3091                    None
#
#                                     case_def_copy_copy1 Category  \
# 3089  AFP MEASLES YELLOW_FEVER CEREBROSPINAL_MENINGI...     None
# 3090  AFP MEASLES YELLOW_FEVER CEREBROSPINAL_MENINGI...     None
# 3091                       AFP MEASLES YELLOW_FEVER NNT     None
#
#      current_feed_back Data_Source Outpatient_only Managing_authority  \
# 3089                 Y        None            None               None
# 3090                 Y        None            None               None
# 3091                 Y        None            None               None
#
#                    designation       supervised_by_who facility_fp_acs  \
# 3089                 STOP_TEAM                 1_MONTH               Y
# 3090                 STOP_TEAM                 1_MONTH               Y
# 3091  WCO_SURVEILLANCE_OFFICER  NOT_IN_THE_PAST_1_YEAR               Y
#
#      joint_supervision                   geometry  FEAT_SEQ
# 3089                 Y  POINT (-11.54843 9.58660)       501
# 3090                 Y  POINT (-11.54838 9.58661)       501
# 3091                 Y  POINT (-11.54779 9.58699)       501

# %%
df.groupby('FEAT_SEQ').agg(count=('ID','count'))\
.sort_values('count', ascending=False).head(20)
# Out:
#           count
# FEAT_SEQ
# 1150         39
# 206          13
# 138          12
# 501          12
# 883          12
# 634          11
# 144          11
# 383          10
# 530           8
# 956           8
# 441           8
# 1015          8
# 571           7
# 22            7
# 485           7
# 957           7
# 746           7
# 826           7
# 794           6
# 454           6

# %% [markdown]
# Findings:
#
# - 39 points in SARA dataset with the same feature sequence
# Almost identical coordinates.

# %%
counts = df.groupby('FEAT_SEQ').agg(count=('ID','count'))\
.sort_values('count', ascending=False)
